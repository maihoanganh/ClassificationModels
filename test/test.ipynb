# %%
N=2 # number of attributes
s=2 # number of classes
t=Vector{Int64}(undef,s) # sample sizes for traint set
Y=Vector{Matrix{Float64}}(undef,s) # input data
Y_train=Vector{Matrix{Float64}}(undef,s) # traint set
Y_test=Vector{Matrix{Float64}}(undef,s) # test set
ratio=0.8 # ratio of train set to test set

for k=1:s 
    # take random samples
    Y[k]=Matrix{Float64}(undef,20,N)
    for j=1:20
        randx=2*rand(Float64,N).-1
        randx=0.5*rand(Float64)*randx./sqrt(sum(randx.^2))
        Y[k][j,:]=randx+(2*k-3)*[0.25;0]
    end
    
    t[k]=ceil(Int64,ratio*size(Y[k],1))
    Y_train[k]=Y[k][1:t[k],:]
    Y_test[k]=Y[k][(t[k]+1):end,:]
end

d=Vector{Int64}(undef,s) # degrees of polynomial estimations
R=Vector{Float64}(undef,s) # radius of ball containing the samples

include("../src/ClassificationModels.jl")
using .ClassificationModels

x=Vector{Vector{Float64}}(undef,s) # coefficients of polynomial estimations

for k=1:s
    println("Class ",k)
    println()
    d[k]=1
    R[k]=1
    
    # train a model
    x[k]=ClassificationModels.solve_opt(N,Y_train[k],t[k],R[k],d[k];
                                    delta=1,s=1,rho=1,numiter=1e3,
                                    eps=1e-3,tol_eig=1e-3,
                                    ball_cons=false,feas_start=false) # Maximum likelihood estimation
    println("------------")
end

eval_PDF=Vector{Function}(undef,s) # evaluate polynomial estimations

for k=1:s
    eval_PDF[k]=ClassificationModels.func_eval_PDF(x[k],N,d[k],R[k],ball_cons=false)
end

classifier(y)=findmax([eval_PDF[k](y) for k=1:s])[2]

predict=Vector{Vector{Int64}}(undef,s) # prediction
numcor=Vector{Int64}(undef,s) # number of corrections

for k=1:s
    predict[k]=[classifier(Y_test[k][j,:]) for j in 1:size(Y_test[k],1)]
    numcor[k]=length(findall(u -> u == k, predict[k]))
end


accuracy=(sum(numcor))/(sum(size(Y_test[k],1) for k=1:s))

println("Accuracy on test set of MLE: ",accuracy)

println()
println("==========================")
println()

Lambda=Vector{Function}(undef,s) # Christoffel function

for k=1:s
    println("Class ",k)
    println()
    d[k]=1
    R[k]=1
    
    # train a model
    Lambda[k]=ClassificationModels.christoffel_func(N,Y_train[k],t[k],d[k],eps=0.0)
    println("------------")
end

classifier2(y)=findmax([Lambda[k](y) for k=1:s])[2]

predict=Vector{Vector{Int64}}(undef,s) # prediction
numcor=Vector{Int64}(undef,s) # number of corrections

for k=1:s
    predict[k]=[classifier2(Y_test[k][j,:]) for j in 1:size(Y_test[k],1)]
    numcor[k]=length(findall(u -> u == k, predict[k]))
end


accuracy=(sum(numcor))/(sum(size(Y_test[k],1) for k=1:s))

println("Accuracy on test set of Christoffel function: ",accuracy)
# Out:
# Class 1
# WARNING: replacing module ClassificationModels.
# iter=951  val=1.0086  norm_vF=0.0056  norm_Axb=0.0558  norm_T=3.8615
# iter=952  val=0.9379  norm_vF=0.0000  norm_Axb=0.0352  norm_T=4.3066
# iter=953  val=1.0117  norm_vF=0.0199  norm_Axb=0.0696  norm_T=4.2447
# iter=954  val=0.9360  norm_vF=0.0000  norm_Axb=0.0325  norm_T=4.3103
# iter=955  val=1.0095  norm_vF=0.0178  norm_Axb=0.0722  norm_T=4.2402
# iter=956  val=0.9340  norm_vF=0.0047  norm_Axb=0.0298  norm_T=4.1715
# iter=957  val=1.0078  norm_vF=0.0165  norm_Axb=0.0634  norm_T=4.2365
# iter=958  val=0.9326  norm_vF=0.0000  norm_Axb=0.0385  norm_T=4.3165
# iter=959  val=1.0057  norm_vF=0.0145  norm_Axb=0.0661  norm_T=4.2311
# iter=960  val=0.9308  norm_vF=0.0064  norm_Axb=0.0357  norm_T=4.1783
# iter=961  val=1.0042  norm_vF=0.0131  norm_Axb=0.0574  norm_T=4.2276
# iter=962  val=0.9295  norm_vF=0.0000  norm_Axb=0.0442  norm_T=4.3227
# iter=963  val=1.0023  norm_vF=0.0110  norm_Axb=0.0601  norm_T=4.2220
# iter=964  val=0.9279  norm_vF=0.0081  norm_Axb=0.0414  norm_T=4.1843
# iter=965  val=1.0008  norm_vF=0.0096  norm_Axb=0.0515  norm_T=4.2192
# iter=966  val=0.9266  norm_vF=0.0000  norm_Axb=0.0499  norm_T=4.3288
# iter=967  val=0.9991  norm_vF=0.0107  norm_Axb=0.0542  norm_T=3.8428
# iter=968  val=0.9299  norm_vF=0.0016  norm_Axb=0.0357  norm_T=3.2266
# iter=969  val=1.0114  norm_vF=0.0066  norm_Axb=0.0604  norm_T=4.2410
# iter=970  val=0.9365  norm_vF=0.0029  norm_Axb=0.0406  norm_T=4.1514
# iter=971  val=1.0097  norm_vF=0.0055  norm_Axb=0.0519  norm_T=4.2482
# iter=972  val=0.9349  norm_vF=0.0000  norm_Axb=0.0493  norm_T=4.3104
# iter=973  val=1.0075  norm_vF=0.0054  norm_Axb=0.0544  norm_T=3.8648
# iter=974  val=0.9378  norm_vF=0.0000  norm_Axb=0.0356  norm_T=4.3014
# iter=975  val=1.0106  norm_vF=0.0195  norm_Axb=0.0680  norm_T=4.2480
# iter=976  val=0.9358  norm_vF=0.0000  norm_Axb=0.0329  norm_T=4.3050
# iter=977  val=1.0084  norm_vF=0.0174  norm_Axb=0.0706  norm_T=4.2436
# iter=978  val=0.9339  norm_vF=0.0044  norm_Axb=0.0303  norm_T=4.1671
# iter=979  val=1.0067  norm_vF=0.0162  norm_Axb=0.0619  norm_T=4.2399
# iter=980  val=0.9324  norm_vF=0.0000  norm_Axb=0.0388  norm_T=4.3113
# iter=981  val=1.0047  norm_vF=0.0141  norm_Axb=0.0645  norm_T=4.2345
# iter=982  val=0.9307  norm_vF=0.0061  norm_Axb=0.0361  norm_T=4.1740
# iter=983  val=1.0031  norm_vF=0.0128  norm_Axb=0.0559  norm_T=4.2310
# iter=984  val=0.9294  norm_vF=0.0000  norm_Axb=0.0446  norm_T=4.3176
# iter=985  val=1.0013  norm_vF=0.0107  norm_Axb=0.0585  norm_T=4.2255
# iter=986  val=0.9277  norm_vF=0.0078  norm_Axb=0.0418  norm_T=4.1801
# iter=987  val=0.9999  norm_vF=0.0093  norm_Axb=0.0500  norm_T=4.2226
# iter=988  val=0.9265  norm_vF=0.0000  norm_Axb=0.0502  norm_T=4.3238
# iter=989  val=0.9981  norm_vF=0.0103  norm_Axb=0.0527  norm_T=3.8458
# iter=990  val=0.9298  norm_vF=0.0014  norm_Axb=0.0363  norm_T=3.2218
# iter=991  val=1.0103  norm_vF=0.0063  norm_Axb=0.0588  norm_T=4.2445
# iter=992  val=0.9362  norm_vF=0.0026  norm_Axb=0.0412  norm_T=4.1488
# iter=993  val=1.0086  norm_vF=0.0052  norm_Axb=0.0502  norm_T=4.2509
# iter=994  val=0.9346  norm_vF=0.0000  norm_Axb=0.0498  norm_T=4.3058
# iter=995  val=1.0064  norm_vF=0.0050  norm_Axb=0.0527  norm_T=3.8672
# iter=996  val=0.9375  norm_vF=0.0000  norm_Axb=0.0363  norm_T=4.2970
# iter=997  val=1.0094  norm_vF=0.0190  norm_Axb=0.0662  norm_T=4.2507
# iter=998  val=0.9355  norm_vF=0.0000  norm_Axb=0.0336  norm_T=4.3007
# iter=999  val=1.0073  norm_vF=0.0170  norm_Axb=0.0687  norm_T=4.2462
# iter=1000  val=0.9337  norm_vF=0.0040  norm_Axb=0.0310  norm_T=4.1636
# ------------
# Class 2
#
# iter=951  val=0.8782  norm_vF=0.0220  norm_Axb=0.0591  norm_T=4.1364
# iter=952  val=0.8067  norm_vF=0.0000  norm_Axb=0.0420  norm_T=4.6037
# iter=953  val=0.8766  norm_vF=0.0195  norm_Axb=0.0634  norm_T=4.1341
# iter=954  val=0.8052  norm_vF=0.0104  norm_Axb=0.0387  norm_T=4.4415
# iter=955  val=0.8762  norm_vF=0.0181  norm_Axb=0.0564  norm_T=4.1344
# iter=956  val=0.8049  norm_vF=0.0033  norm_Axb=0.0455  norm_T=4.4402
# iter=957  val=0.8759  norm_vF=0.0168  norm_Axb=0.0494  norm_T=4.1352
# iter=958  val=0.8047  norm_vF=0.0000  norm_Axb=0.0524  norm_T=4.6099
# iter=959  val=0.8741  norm_vF=0.0146  norm_Axb=0.0527  norm_T=4.1151
# iter=960  val=0.8034  norm_vF=0.0066  norm_Axb=0.0490  norm_T=4.4484
# iter=961  val=0.8738  norm_vF=0.0132  norm_Axb=0.0457  norm_T=4.1260
# iter=962  val=0.8030  norm_vF=0.0000  norm_Axb=0.0559  norm_T=4.6154
# iter=963  val=0.8721  norm_vF=0.0113  norm_Axb=0.0489  norm_T=3.9517
# iter=964  val=0.8040  norm_vF=0.0078  norm_Axb=0.0497  norm_T=4.3041
# iter=965  val=0.8737  norm_vF=0.0119  norm_Axb=0.0442  norm_T=4.1310
# iter=966  val=0.8030  norm_vF=0.0000  norm_Axb=0.0569  norm_T=4.4422
# iter=967  val=0.8735  norm_vF=0.0105  norm_Axb=0.0376  norm_T=4.1266
# iter=968  val=0.8030  norm_vF=0.0000  norm_Axb=0.0637  norm_T=4.6175
# iter=969  val=0.8717  norm_vF=0.0084  norm_Axb=0.0408  norm_T=4.0941
# iter=970  val=0.8018  norm_vF=0.0031  norm_Axb=0.0602  norm_T=4.4512
# iter=971  val=0.8715  norm_vF=0.0071  norm_Axb=0.0339  norm_T=4.1184
# iter=972  val=0.8014  norm_vF=0.0000  norm_Axb=0.0671  norm_T=4.6237
# iter=973  val=0.8699  norm_vF=0.0070  norm_Axb=0.0372  norm_T=3.6240
# iter=974  val=0.8073  norm_vF=0.0000  norm_Axb=0.0518  norm_T=4.6012
# iter=975  val=0.8765  norm_vF=0.0199  norm_Axb=0.0524  norm_T=4.1333
# iter=976  val=0.8060  norm_vF=0.0000  norm_Axb=0.0475  norm_T=4.6063
# iter=977  val=0.8749  norm_vF=0.0174  norm_Axb=0.0566  norm_T=4.1334
# iter=978  val=0.8045  norm_vF=0.0067  norm_Axb=0.0441  norm_T=4.4420
# iter=979  val=0.8746  norm_vF=0.0160  norm_Axb=0.0498  norm_T=4.1307
# iter=980  val=0.8043  norm_vF=0.0000  norm_Axb=0.0508  norm_T=4.6118
# iter=981  val=0.8729  norm_vF=0.0139  norm_Axb=0.0530  norm_T=4.0886
# iter=982  val=0.8034  norm_vF=0.0096  norm_Axb=0.0473  norm_T=4.4382
# iter=983  val=0.8727  norm_vF=0.0128  norm_Axb=0.0462  norm_T=4.1264
# iter=984  val=0.8028  norm_vF=0.0026  norm_Axb=0.0542  norm_T=4.4484
# iter=985  val=0.8725  norm_vF=0.0114  norm_Axb=0.0395  norm_T=4.1232
# iter=986  val=0.8027  norm_vF=0.0000  norm_Axb=0.0609  norm_T=4.6180
# iter=987  val=0.8708  norm_vF=0.0093  norm_Axb=0.0427  norm_T=4.0747
# iter=988  val=0.8019  norm_vF=0.0054  norm_Axb=0.0572  norm_T=4.4399
# iter=989  val=0.8708  norm_vF=0.0082  norm_Axb=0.0360  norm_T=4.1195
# iter=990  val=0.8013  norm_vF=0.0000  norm_Axb=0.0640  norm_T=4.6236
# iter=991  val=0.8692  norm_vF=0.0092  norm_Axb=0.0393  norm_T=3.6168
# iter=992  val=0.8073  norm_vF=0.0000  norm_Axb=0.0485  norm_T=4.6007
# iter=993  val=0.8759  norm_vF=0.0209  norm_Axb=0.0547  norm_T=4.1360
# iter=994  val=0.8060  norm_vF=0.0000  norm_Axb=0.0444  norm_T=4.6057
# iter=995  val=0.8742  norm_vF=0.0185  norm_Axb=0.0587  norm_T=4.1307
# iter=996  val=0.8045  norm_vF=0.0087  norm_Axb=0.0411  norm_T=4.4433
# iter=997  val=0.8740  norm_vF=0.0171  norm_Axb=0.0519  norm_T=4.1300
# iter=998  val=0.8044  norm_vF=0.0017  norm_Axb=0.0478  norm_T=4.4420
# iter=999  val=0.8737  norm_vF=0.0157  norm_Axb=0.0451  norm_T=4.1309
# iter=1000  val=0.8042  norm_vF=0.0000  norm_Axb=0.0545  norm_T=4.6119
# ------------
# Accuracy on test set of MLE: 0.625
#
# ==========================
#
# Class 1
#
# ------------
# Class 2
#
# ------------
# Accuracy on test set of Christoffel function: 0.625
