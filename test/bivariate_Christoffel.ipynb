# %%
#=
N=2
d=2
t=20
Y1=Matrix{Float64}(undef,t,N)
randx=zeros(Float64,N)
for j=1:t
    randx=2*rand(Float64,N).-1
    randx=0.5*rand(Float64)*randx./sqrt(sum(randx.^2))
    Y1[j,:]=randx-[0.25;0]
end

Y2=Matrix{Float64}(undef,t,N)
randx=zeros(Float64,N)
for j=1:t
    randx=2*rand(Float64,N).-1
    randx=0.5*rand(Float64)*randx./sqrt(sum(randx.^2))
    Y2[j,:]=randx+[0.25;0]
end
=#

# %%
#=
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
output_file = open(data*"/bivariate_data.jl","w")

write(output_file, "d = $(d)")
write(output_file, "; \n \n")
write(output_file, "N = $(N)")
write(output_file, "; \n \n")
write(output_file, "t = $(t)")
write(output_file, "; \n \n")
write(output_file, "Y1 = ")
show(output_file, Y1)
write(output_file, "; \n \n")
write(output_file, "Y2 = ")
show(output_file, Y2)
write(output_file, "; \n \n")

close(output_file)
=#

# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
include(data*"/bivariate_data.jl");

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

Lambda1=ClassificationModels.christoffel_func(N,Y1,t,d);
# Out:
# ┌ Info: Precompiling Arpack [7d9fca2a-8960-54d3-9f78-7d1dccf2cb97]
# └ @ Base loading.jl:1273
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1273
# ┌ Info: Precompiling SCS [c946c3f1-0d1f-5ce8-9dea-7daa1f7e2d13]
# └ @ Base loading.jl:1273
# ┌ Info: Precompiling Convex [f65535da-76fb-5f13-bab9-19810c17039a]
# └ @ Base loading.jl:1273
# ┌ Info: Precompiling COSMO [1e616198-aa4e-51ec-90a2-23f7fbd31d8d]
# └ @ Base loading.jl:1273
# ┌ Info: Precompiling CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b]
# └ @ Base loading.jl:1273
# ┌ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1273

# %%
using Plots

import Contour: contours, levels, level, lines, coordinates

p_approx1(x1,x2)=Lambda1([x1;x2])

x1s = -1:0.01:1
x2s = -1:0.01:1

contour(x1s, x2s, p_approx1,fill=true,title = "estimation 1")

scatter!(Y1[:,1], Y1[:,2],label ="sample 1",color="Green")
scatter!(Y2[:,1], Y2[:,2],label ="sample 2",color="Red")
# Out:
# ┌ Info: Precompiling Contour [d38c429a-6771-53c6-b99e-75d170b6e991]
# └ @ Base loading.jl:1273

# %%
savefig(data*"/bivariate_classification_estimation1_CF.png")

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

Lambda2=ClassificationModels.christoffel_func(N,Y2,t,d);
# Out:
# WARNING: replacing module ClassificationModels.

# %%
using Plots

import Contour: contours, levels, level, lines, coordinates

p_approx2(x1,x2)=Lambda2([x1;x2])

x1s = -1:0.01:1
x2s = -1:0.01:1

contour(x1s, x2s, p_approx2,fill=true,title = "estimation 2")

scatter!(Y1[:,1], Y1[:,2],label ="sample 1",color="Green")
scatter!(Y2[:,1], Y2[:,2],label ="sample 2",color="Red")

# %%
savefig(data*"/bivariate_classification_estimation2_CF.png")

# %%
binomial(43+2,2)
# Out:
# 990
