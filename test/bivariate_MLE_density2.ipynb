# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
include(data*"/bivariate_MLE_density_data.jl");

# %%
d=5
# Out:
# 5

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

R=1

x=ClassificationModels.solve_opt(N,Y,t,R,d,delta=1,s=1,rho=1,numiter=2e5,eps=1e-4,tol_eig=1e-3,ball_cons=true);
# Out:
# iter=199951  val=0.9013  norm_vF=0.0309  norm_Axb=0.0069  norm_T=13.0227
# iter=199952  val=0.8949  norm_vF=0.0317  norm_Axb=0.0006  norm_T=4.5723
# iter=199953  val=0.8952  norm_vF=0.0321  norm_Axb=0.0054  norm_T=9.2479
# iter=199954  val=0.8965  norm_vF=0.0318  norm_Axb=0.0018  norm_T=10.4071
# iter=199955  val=0.8924  norm_vF=0.0324  norm_Axb=0.0041  norm_T=7.1662
# iter=199956  val=0.8991  norm_vF=0.0310  norm_Axb=0.0038  norm_T=10.5719
# iter=199957  val=0.8938  norm_vF=0.0321  norm_Axb=0.0017  norm_T=7.0699
# iter=199958  val=0.9008  norm_vF=0.0309  norm_Axb=0.0063  norm_T=13.2281
# iter=199959  val=0.8944  norm_vF=0.0318  norm_Axb=0.0001  norm_T=7.0009
# iter=199960  val=0.9017  norm_vF=0.0306  norm_Axb=0.0082  norm_T=12.6849
# iter=199961  val=0.8955  norm_vF=0.0316  norm_Axb=0.0020  norm_T=4.9104
# iter=199962  val=0.8959  norm_vF=0.0322  norm_Axb=0.0043  norm_T=9.2775
# iter=199963  val=0.8970  norm_vF=0.0314  norm_Axb=0.0025  norm_T=8.9557
# ...

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

eval_PDF=ClassificationModels.func_eval_PDF(x,N,d,R,ball_cons=true)
# Out:
# WARNING: replacing module ClassificationModels.
# (::Main.ClassificationModels.var"#eval_PDF#17"{Array{Float64,1},Int64,Int64,Array{UInt64,1},Array{Array{Float64,1},1},Array{SparseArrays.SparseMatrixCSC{UInt64,Ti} where Ti<:Integer,1},Int64,Array{Int64,1},SparseArrays.SparseMatrixCSC{UInt64,Int64}}) (generic function with 1 method)

# %%
using Plots

import Contour: contours, levels, level, lines, coordinates

p_approx(x1,x2)=eval_PDF([x1;x2])

x1s = -1:0.01:1
x2s = -1:0.01:1

contour(x1s, x2s, p_approx,fill=true,title = "d = $(d)")

scatter!(Y[:,1], Y[:,2],label ="sample")

# %%
savefig(data*"/bivariate_pdf_degree$(d).png")
