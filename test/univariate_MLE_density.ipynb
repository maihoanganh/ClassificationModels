# %%
#=
N=1
t=50
Y=Matrix{Float64}(undef,t,N)
randx=zeros(Float64,N)
for j=1:t
    randx=2*rand(Float64,N).-1
    randx=rand(Float64)*randx./sqrt(sum(randx.^2))
    Y[j,:]=randx
end
=#

# %%
#=
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
output_file = open(data*"/univariate_MLE_density_data.jl","w")


write(output_file, "N = $(N)")
write(output_file, "; \n \n")
write(output_file, "t = $(t)")
write(output_file, "; \n \n")
write(output_file, "Y = ")
show(output_file, Y)
write(output_file, "; \n \n")

close(output_file)
=#

# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
include(data*"/univariate_MLE_density_data.jl");

# %%
using Plots

r=1
p_exact(z)=0.5
scatter(Y[:,1], zeros(Float64,t),label ="sample")
plot!(p_exact, -r, r, label ="exact")

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

d=5
R=1

x=ClassificationModels.solve_opt(N,Y,t,R,d,delta=1,s=1,rho=1,numiter=1e5,eps=1e-4,tol_eig=1e-3,ball_cons=true);
# Out:
# iter=99951  val=0.8195  norm_vF=0.0362  norm_Axb=0.0006  norm_T=5.3425
# iter=99952  val=0.8277  norm_vF=0.0352  norm_Axb=0.0053  norm_T=9.0530
# iter=99953  val=0.8203  norm_vF=0.0362  norm_Axb=0.0006  norm_T=5.7025
# iter=99954  val=0.8270  norm_vF=0.0352  norm_Axb=0.0056  norm_T=8.7408
# iter=99955  val=0.8204  norm_vF=0.0362  norm_Axb=0.0006  norm_T=5.8183
# iter=99956  val=0.8263  norm_vF=0.0354  norm_Axb=0.0053  norm_T=8.7093
# iter=99957  val=0.8194  norm_vF=0.0362  norm_Axb=0.0006  norm_T=5.3057
# iter=99958  val=0.8277  norm_vF=0.0353  norm_Axb=0.0053  norm_T=9.1701
# iter=99959  val=0.8202  norm_vF=0.0362  norm_Axb=0.0006  norm_T=5.6520
# iter=99960  val=0.8272  norm_vF=0.0352  norm_Axb=0.0057  norm_T=8.8222
# iter=99961  val=0.8204  norm_vF=0.0362  norm_Axb=0.0005  norm_T=5.7977
# iter=99962  val=0.8263  norm_vF=0.0354  norm_Axb=0.0053  norm_T=8.6444
# iter=99963  val=0.8195  norm_vF=0.0362  norm_Axb=0.0006  norm_T=5.3527
# ...

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

eval_PDF=ClassificationModels.func_eval_PDF(x,N,d,R,ball_cons=true)
# Out:
# WARNING: replacing module ClassificationModels.
# (::Main.ClassificationModels.var"#eval_PDF#17"{Array{Float64,1},Int64,Int64,Array{UInt64,1},Array{Array{Float64,1},1},Array{SparseArrays.SparseMatrixCSC{UInt64,Ti} where Ti<:Integer,1},Int64,Array{Int64,1},SparseArrays.SparseMatrixCSC{UInt64,Int64}}) (generic function with 1 method)

# %%
p_approx(z)=eval_PDF([z;zeros(N-1)])
plot!(p_approx, -r, r, label = "d = $(d)",#=legend=:bottomright,=#title = "t = $(t)")

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

d=10
R=1

x=ClassificationModels.solve_opt(N,Y,t,R,d,delta=1,s=1,rho=1,numiter=1e5,eps=1e-4,tol_eig=1e-3,ball_cons=true);
# Out:
# iter=99951  val=0.5991  norm_vF=0.0000  norm_Axb=0.0018  norm_T=3.9743
# iter=99952  val=0.6083  norm_vF=0.0000  norm_Axb=0.0082  norm_T=2.4433
# iter=99953  val=0.5990  norm_vF=0.0000  norm_Axb=0.0017  norm_T=3.9735
# iter=99954  val=0.6081  norm_vF=0.0005  norm_Axb=0.0083  norm_T=4.5518
# iter=99955  val=0.6003  norm_vF=0.0000  norm_Axb=0.0007  norm_T=3.9712
# iter=99956  val=0.6094  norm_vF=0.0000  norm_Axb=0.0093  norm_T=2.4471
# iter=99957  val=0.6001  norm_vF=0.0000  norm_Axb=0.0007  norm_T=3.9704
# iter=99958  val=0.6092  norm_vF=0.0003  norm_Axb=0.0094  norm_T=4.5637
# iter=99959  val=0.6013  norm_vF=0.0000  norm_Axb=0.0003  norm_T=2.4169
# iter=99960  val=0.5921  norm_vF=0.0000  norm_Axb=0.0096  norm_T=4.0011
# iter=99961  val=0.6012  norm_vF=0.0000  norm_Axb=0.0004  norm_T=2.4165
# iter=99962  val=0.5919  norm_vF=0.0000  norm_Axb=0.0096  norm_T=4.0003
# iter=99963  val=0.6010  norm_vF=0.0000  norm_Axb=0.0005  norm_T=2.4161
# ...

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

eval_PDF=ClassificationModels.func_eval_PDF(x,N,d,R,ball_cons=true)
# Out:
# WARNING: replacing module ClassificationModels.
# (::Main.ClassificationModels.var"#eval_PDF#17"{Array{Float64,1},Int64,Int64,Array{UInt64,1},Array{Array{Float64,1},1},Array{SparseArrays.SparseMatrixCSC{UInt64,Ti} where Ti<:Integer,1},Int64,Array{Int64,1},SparseArrays.SparseMatrixCSC{UInt64,Int64}}) (generic function with 1 method)

# %%
p_approx(z)=eval_PDF([z;zeros(N-1)])
plot!(p_approx, -r, r, label = "d = $(d)",#=legend=:bottomright,=#title = "t = $(t)")

# %%
savefig(data*"/univariate_pdf_numsamp$(t).png")
