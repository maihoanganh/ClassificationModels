# %%
include("/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_bivariate_Christoffel()
# Out:
# WARNING: replacing module ClassificationModels.

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_bivariate_Christoffel2()
# Out:
# WARNING: replacing module ClassificationModels.

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_bivariate_MLE()
# Out:
# iter=99951  val=0.1806  norm_vF=0.0018  norm_Axb=0.0045  norm_T=5.7460
# iter=99952  val=0.1765  norm_vF=0.0005  norm_Axb=0.0075  norm_T=6.6680
# iter=99953  val=0.1803  norm_vF=0.0015  norm_Axb=0.0030  norm_T=5.9024
# iter=99954  val=0.1760  norm_vF=0.0007  norm_Axb=0.0094  norm_T=6.8298
# iter=99955  val=0.1796  norm_vF=0.0012  norm_Axb=0.0011  norm_T=5.6092
# iter=99956  val=0.1754  norm_vF=0.0005  norm_Axb=0.0111  norm_T=7.3117
# iter=99957  val=0.1789  norm_vF=0.0007  norm_Axb=0.0004  norm_T=3.3195
# iter=99958  val=0.1830  norm_vF=0.0029  norm_Axb=0.0099  norm_T=5.9933
# iter=99959  val=0.1784  norm_vF=0.0016  norm_Axb=0.0016  norm_T=6.6839
# iter=99960  val=0.1822  norm_vF=0.0026  norm_Axb=0.0087  norm_T=5.9471
# iter=99961  val=0.1778  norm_vF=0.0009  norm_Axb=0.0037  norm_T=6.7162
# iter=99962  val=0.1815  norm_vF=0.0023  norm_Axb=0.0067  norm_T=5.9434
# iter=99963  val=0.1770  norm_vF=0.0009  norm_Axb=0.0057  norm_T=6.6604
# iter=99964  val=0.1809  norm_vF=0.0021  norm_Axb=0.0049  norm_T=5.7699
# iter=99965  val=0.1768  norm_vF=0.0007  norm_Axb=0.0072  norm_T=7.2138
# iter=99966  val=0.1803  norm_vF=0.0016  norm_Axb=0.0035  norm_T=5.8926
# iter=99967  val=0.1760  norm_vF=0.0003  norm_Axb=0.0089  norm_T=6.7077
# iter=99968  val=0.1797  norm_vF=0.0013  norm_Axb=0.0016  norm_T=5.5931
# iter=99969  val=0.1755  norm_vF=0.0006  norm_Axb=0.0106  norm_T=6.7070
# iter=99970  val=0.1793  norm_vF=0.0010  norm_Axb=0.0001  norm_T=2.8969
# iter=99971  val=0.1832  norm_vF=0.0028  norm_Axb=0.0105  norm_T=6.0134
# iter=99972  val=0.1786  norm_vF=0.0010  norm_Axb=0.0016  norm_T=6.6716
# iter=99973  val=0.1824  norm_vF=0.0026  norm_Axb=0.0086  norm_T=5.9136
# iter=99974  val=0.1781  norm_vF=0.0010  norm_Axb=0.0037  norm_T=6.7440
# iter=99975  val=0.1817  norm_vF=0.0023  norm_Axb=0.0067  norm_T=5.9729
# iter=99976  val=0.1772  norm_vF=0.0004  norm_Axb=0.0057  norm_T=7.1215
# iter=99977  val=0.1808  norm_vF=0.0019  norm_Axb=0.0049  norm_T=5.7563
# iter=99978  val=0.1768  norm_vF=0.0008  norm_Axb=0.0071  norm_T=6.7211
# iter=99979  val=0.1806  norm_vF=0.0016  norm_Axb=0.0035  norm_T=5.9115
# iter=99980  val=0.1763  norm_vF=0.0004  norm_Axb=0.0089  norm_T=7.2587
# iter=99981  val=0.1799  norm_vF=0.0011  norm_Axb=0.0017  norm_T=5.5831
# iter=99982  val=0.1757  norm_vF=0.0007  norm_Axb=0.0104  norm_T=6.8235
# iter=99983  val=0.1793  norm_vF=0.0008  norm_Axb=0.0000  norm_T=5.1509
# iter=99984  val=0.1762  norm_vF=0.0000  norm_Axb=0.0081  norm_T=6.2944
# iter=99985  val=0.1804  norm_vF=0.0026  norm_Axb=0.0046  norm_T=5.7513
# iter=99986  val=0.1763  norm_vF=0.0000  norm_Axb=0.0074  norm_T=6.2943
# iter=99987  val=0.1805  norm_vF=0.0024  norm_Axb=0.0054  norm_T=5.9154
# iter=99988  val=0.1762  norm_vF=0.0002  norm_Axb=0.0070  norm_T=6.6214
# iter=99989  val=0.1800  norm_vF=0.0021  norm_Axb=0.0035  norm_T=5.9730
# iter=99990  val=0.1755  norm_vF=0.0001  norm_Axb=0.0089  norm_T=6.6723
# iter=99991  val=0.1793  norm_vF=0.0019  norm_Axb=0.0016  norm_T=5.6110
# iter=99992  val=0.1751  norm_vF=0.0001  norm_Axb=0.0105  norm_T=7.1918
# iter=99993  val=0.1787  norm_vF=0.0013  norm_Axb=0.0001  norm_T=5.9221
# iter=99994  val=0.1743  norm_vF=0.0001  norm_Axb=0.0123  norm_T=6.5301
# iter=99995  val=0.1783  norm_vF=0.0011  norm_Axb=0.0003  norm_T=3.4056
# iter=99996  val=0.1826  norm_vF=0.0031  norm_Axb=0.0105  norm_T=6.0834
# iter=99997  val=0.1779  norm_vF=0.0016  norm_Axb=0.0015  norm_T=6.3395
# iter=99998  val=0.1815  norm_vF=0.0028  norm_Axb=0.0085  norm_T=5.8711
# iter=99999  val=0.1772  norm_vF=0.0014  norm_Axb=0.0038  norm_T=6.7363
# iter=100000  val=0.1808  norm_vF=0.0025  norm_Axb=0.0066  norm_T=5.9505
# WARNING: replacing module ClassificationModels.

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_bivariate_MLE2()
# Out:
# iter=99951  val=0.1352  norm_vF=0.0014  norm_Axb=0.0022  norm_T=5.9389
# iter=99952  val=0.1310  norm_vF=0.0002  norm_Axb=0.0102  norm_T=7.0178
# iter=99953  val=0.1345  norm_vF=0.0010  norm_Axb=0.0001  norm_T=5.6894
# iter=99954  val=0.1306  norm_vF=0.0005  norm_Axb=0.0120  norm_T=7.0311
# iter=99955  val=0.1339  norm_vF=0.0006  norm_Axb=0.0016  norm_T=2.9281
# iter=99956  val=0.1376  norm_vF=0.0024  norm_Axb=0.0090  norm_T=6.0427
# iter=99957  val=0.1333  norm_vF=0.0013  norm_Axb=0.0031  norm_T=6.6892
# iter=99958  val=0.1369  norm_vF=0.0022  norm_Axb=0.0071  norm_T=5.8843
# iter=99959  val=0.1329  norm_vF=0.0009  norm_Axb=0.0051  norm_T=6.7852
# iter=99960  val=0.1363  norm_vF=0.0018  norm_Axb=0.0052  norm_T=5.9772
# iter=99961  val=0.1321  norm_vF=0.0004  norm_Axb=0.0072  norm_T=6.7386
# iter=99962  val=0.1357  norm_vF=0.0016  norm_Axb=0.0032  norm_T=5.8154
# iter=99963  val=0.1318  norm_vF=0.0001  norm_Axb=0.0088  norm_T=7.3893
# iter=99964  val=0.1352  norm_vF=0.0010  norm_Axb=0.0018  norm_T=5.9241
# iter=99965  val=0.1312  norm_vF=0.0004  norm_Axb=0.0105  norm_T=6.7860
# iter=99966  val=0.1346  norm_vF=0.0007  norm_Axb=0.0002  norm_T=2.8409
# iter=99967  val=0.1383  norm_vF=0.0025  norm_Axb=0.0105  norm_T=5.9963
# iter=99968  val=0.1340  norm_vF=0.0017  norm_Axb=0.0016  norm_T=6.6290
# iter=99969  val=0.1377  norm_vF=0.0022  norm_Axb=0.0086  norm_T=5.9616
# iter=99970  val=0.1336  norm_vF=0.0010  norm_Axb=0.0037  norm_T=7.0668
# iter=99971  val=0.1370  norm_vF=0.0018  norm_Axb=0.0067  norm_T=5.9812
# iter=99972  val=0.1328  norm_vF=0.0012  norm_Axb=0.0057  norm_T=6.9972
# iter=99973  val=0.1363  norm_vF=0.0014  norm_Axb=0.0046  norm_T=5.4865
# iter=99974  val=0.1328  norm_vF=0.0010  norm_Axb=0.0047  norm_T=5.2409
# iter=99975  val=0.1368  norm_vF=0.0019  norm_Axb=0.0055  norm_T=6.0157
# iter=99976  val=0.1325  norm_vF=0.0006  norm_Axb=0.0069  norm_T=6.7323
# iter=99977  val=0.1361  norm_vF=0.0016  norm_Axb=0.0035  norm_T=5.8515
# iter=99978  val=0.1321  norm_vF=0.0001  norm_Axb=0.0085  norm_T=7.2431
# iter=99979  val=0.1355  norm_vF=0.0011  norm_Axb=0.0021  norm_T=5.9522
# iter=99980  val=0.1314  norm_vF=0.0003  norm_Axb=0.0103  norm_T=6.7805
# iter=99981  val=0.1350  norm_vF=0.0008  norm_Axb=0.0001  norm_T=5.9577
# iter=99982  val=0.1309  norm_vF=0.0001  norm_Axb=0.0123  norm_T=6.7852
# iter=99983  val=0.1343  norm_vF=0.0005  norm_Axb=0.0019  norm_T=3.3540
# iter=99984  val=0.1382  norm_vF=0.0025  norm_Axb=0.0087  norm_T=5.9941
# iter=99985  val=0.1339  norm_vF=0.0008  norm_Axb=0.0034  norm_T=6.4620
# iter=99986  val=0.1374  norm_vF=0.0021  norm_Axb=0.0066  norm_T=5.9392
# iter=99987  val=0.1333  norm_vF=0.0005  norm_Axb=0.0056  norm_T=6.8123
# iter=99988  val=0.1367  norm_vF=0.0017  norm_Axb=0.0046  norm_T=6.0217
# iter=99989  val=0.1325  norm_vF=0.0002  norm_Axb=0.0078  norm_T=7.3891
# iter=99990  val=0.1359  norm_vF=0.0011  norm_Axb=0.0028  norm_T=5.9487
# iter=99991  val=0.1318  norm_vF=0.0004  norm_Axb=0.0096  norm_T=6.7511
# iter=99992  val=0.1354  norm_vF=0.0008  norm_Axb=0.0008  norm_T=5.9195
# iter=99993  val=0.1313  norm_vF=0.0001  norm_Axb=0.0116  norm_T=7.2909
# iter=99994  val=0.1347  norm_vF=0.0005  norm_Axb=0.0010  norm_T=6.7985
# iter=99995  val=0.1380  norm_vF=0.0030  norm_Axb=0.0091  norm_T=6.0004
# iter=99996  val=0.1338  norm_vF=0.0002  norm_Axb=0.0033  norm_T=6.1499
# iter=99997  val=0.1376  norm_vF=0.0026  norm_Axb=0.0070  norm_T=5.9973
# iter=99998  val=0.1334  norm_vF=0.0000  norm_Axb=0.0052  norm_T=6.3171
# iter=99999  val=0.1373  norm_vF=0.0025  norm_Axb=0.0076  norm_T=5.9882
# iter=100000  val=0.1331  norm_vF=0.0003  norm_Axb=0.0048  norm_T=6.7480
# WARNING: replacing module ClassificationModels.

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_bivariate_MLE_density()
# Out:
# iter=99951  val=0.9380  norm_vF=0.0000  norm_Axb=0.0061  norm_T=4.7233
# iter=99952  val=0.9501  norm_vF=0.0001  norm_Axb=0.0068  norm_T=4.4510
# iter=99953  val=0.9394  norm_vF=0.0000  norm_Axb=0.0045  norm_T=4.7140
# iter=99954  val=0.9516  norm_vF=0.0002  norm_Axb=0.0083  norm_T=5.3565
# iter=99955  val=0.9401  norm_vF=0.0000  norm_Axb=0.0040  norm_T=4.7109
# iter=99956  val=0.9522  norm_vF=0.0000  norm_Axb=0.0089  norm_T=3.4999
# iter=99957  val=0.9400  norm_vF=0.0000  norm_Axb=0.0039  norm_T=4.7111
# iter=99958  val=0.9522  norm_vF=0.0000  norm_Axb=0.0089  norm_T=3.4994
# iter=99959  val=0.9400  norm_vF=0.0000  norm_Axb=0.0039  norm_T=4.7113
# iter=99960  val=0.9521  norm_vF=0.0002  norm_Axb=0.0089  norm_T=5.1785
# iter=99961  val=0.9409  norm_vF=0.0000  norm_Axb=0.0032  norm_T=4.7069
# iter=99962  val=0.9530  norm_vF=0.0000  norm_Axb=0.0097  norm_T=3.5043
# iter=99963  val=0.9408  norm_vF=0.0000  norm_Axb=0.0032  norm_T=4.7071
# iter=99964  val=0.9530  norm_vF=0.0000  norm_Axb=0.0097  norm_T=3.5038
# iter=99965  val=0.9408  norm_vF=0.0000  norm_Axb=0.0031  norm_T=4.7073
# iter=99966  val=0.9529  norm_vF=0.0001  norm_Axb=0.0097  norm_T=5.3689
# iter=99967  val=0.9414  norm_vF=0.0000  norm_Axb=0.0026  norm_T=4.7043
# iter=99968  val=0.9536  norm_vF=0.0000  norm_Axb=0.0103  norm_T=3.5069
# iter=99969  val=0.9414  norm_vF=0.0000  norm_Axb=0.0025  norm_T=4.7046
# iter=99970  val=0.9535  norm_vF=0.0000  norm_Axb=0.0103  norm_T=4.9071
# iter=99971  val=0.9426  norm_vF=0.0000  norm_Axb=0.0014  norm_T=4.6984
# iter=99972  val=0.9548  norm_vF=0.0000  norm_Axb=0.0115  norm_T=5.3388
# iter=99973  val=0.9433  norm_vF=0.0000  norm_Axb=0.0006  norm_T=4.6956
# iter=99974  val=0.9556  norm_vF=0.0000  norm_Axb=0.0123  norm_T=4.4765
# iter=99975  val=0.9448  norm_vF=0.0000  norm_Axb=0.0009  norm_T=3.4566
# iter=99976  val=0.9327  norm_vF=0.0000  norm_Axb=0.0119  norm_T=4.7525
# iter=99977  val=0.9447  norm_vF=0.0000  norm_Axb=0.0010  norm_T=3.4562
# iter=99978  val=0.9326  norm_vF=0.0000  norm_Axb=0.0119  norm_T=4.7527
# iter=99979  val=0.9447  norm_vF=0.0000  norm_Axb=0.0010  norm_T=3.4557
# iter=99980  val=0.9326  norm_vF=0.0000  norm_Axb=0.0119  norm_T=4.7529
# iter=99981  val=0.9446  norm_vF=0.0000  norm_Axb=0.0010  norm_T=3.4553
# iter=99982  val=0.9325  norm_vF=0.0000  norm_Axb=0.0119  norm_T=4.7531
# iter=99983  val=0.9446  norm_vF=0.0000  norm_Axb=0.0010  norm_T=3.4549
# iter=99984  val=0.9325  norm_vF=0.0000  norm_Axb=0.0119  norm_T=4.7533
# iter=99985  val=0.9445  norm_vF=0.0000  norm_Axb=0.0010  norm_T=3.4545
# iter=99986  val=0.9324  norm_vF=0.0000  norm_Axb=0.0118  norm_T=4.7535
# iter=99987  val=0.9445  norm_vF=0.0000  norm_Axb=0.0010  norm_T=4.7645
# iter=99988  val=0.9338  norm_vF=0.0000  norm_Axb=0.0106  norm_T=4.7463
# iter=99989  val=0.9459  norm_vF=0.0000  norm_Axb=0.0023  norm_T=3.4623
# iter=99990  val=0.9338  norm_vF=0.0000  norm_Axb=0.0106  norm_T=4.7465
# iter=99991  val=0.9458  norm_vF=0.0000  norm_Axb=0.0023  norm_T=3.4619
# iter=99992  val=0.9337  norm_vF=0.0000  norm_Axb=0.0105  norm_T=4.7467
# iter=99993  val=0.9458  norm_vF=0.0000  norm_Axb=0.0023  norm_T=3.4615
# iter=99994  val=0.9337  norm_vF=0.0000  norm_Axb=0.0105  norm_T=4.7469
# iter=99995  val=0.9457  norm_vF=0.0000  norm_Axb=0.0023  norm_T=3.4611
# iter=99996  val=0.9336  norm_vF=0.0000  norm_Axb=0.0105  norm_T=4.7470
# iter=99997  val=0.9457  norm_vF=0.0001  norm_Axb=0.0023  norm_T=4.9579
# iter=99998  val=0.9348  norm_vF=0.0000  norm_Axb=0.0095  norm_T=4.7411
# iter=99999  val=0.9468  norm_vF=0.0000  norm_Axb=0.0033  norm_T=3.4677
# iter=100000  val=0.9347  norm_vF=0.0000  norm_Axb=0.0095  norm_T=4.7413
# WARNING: replacing module ClassificationModels.

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_bivariate_MLE_density2()
# Out:
# iter=199951  val=0.8642  norm_vF=0.0000  norm_Axb=0.0062  norm_T=5.2266
# iter=199952  val=0.8568  norm_vF=0.0000  norm_Axb=0.0025  norm_T=5.4640
# iter=199953  val=0.8653  norm_vF=0.0001  norm_Axb=0.0072  norm_T=5.9251
# iter=199954  val=0.8575  norm_vF=0.0000  norm_Axb=0.0016  norm_T=5.4607
# iter=199955  val=0.8659  norm_vF=0.0003  norm_Axb=0.0081  norm_T=5.3099
# iter=199956  val=0.8585  norm_vF=0.0000  norm_Axb=0.0004  norm_T=5.4556
# iter=199957  val=0.8670  norm_vF=0.0006  norm_Axb=0.0093  norm_T=5.9074
# iter=199958  val=0.8591  norm_vF=0.0000  norm_Axb=0.0003  norm_T=3.3331
# iter=199959  val=0.8506  norm_vF=0.0000  norm_Axb=0.0095  norm_T=5.4980
# iter=199960  val=0.8590  norm_vF=0.0000  norm_Axb=0.0003  norm_T=3.3329
# iter=199961  val=0.8505  norm_vF=0.0000  norm_Axb=0.0094  norm_T=5.4979
# iter=199962  val=0.8589  norm_vF=0.0001  norm_Axb=0.0003  norm_T=4.6154
# iter=199963  val=0.8523  norm_vF=0.0000  norm_Axb=0.0076  norm_T=5.4889
# iter=199964  val=0.8607  norm_vF=0.0000  norm_Axb=0.0021  norm_T=3.3422
# iter=199965  val=0.8522  norm_vF=0.0000  norm_Axb=0.0076  norm_T=5.4888
# iter=199966  val=0.8606  norm_vF=0.0000  norm_Axb=0.0022  norm_T=3.3421
# iter=199967  val=0.8521  norm_vF=0.0000  norm_Axb=0.0076  norm_T=5.4887
# iter=199968  val=0.8605  norm_vF=0.0002  norm_Axb=0.0022  norm_T=5.0471
# iter=199969  val=0.8533  norm_vF=0.0000  norm_Axb=0.0063  norm_T=5.4822
# iter=199970  val=0.8617  norm_vF=0.0002  norm_Axb=0.0035  norm_T=4.8555
# iter=199971  val=0.8548  norm_vF=0.0000  norm_Axb=0.0046  norm_T=5.4746
# iter=199972  val=0.8632  norm_vF=0.0001  norm_Axb=0.0051  norm_T=5.5972
# iter=199973  val=0.8554  norm_vF=0.0000  norm_Axb=0.0040  norm_T=5.4712
# iter=199974  val=0.8639  norm_vF=0.0001  norm_Axb=0.0058  norm_T=4.9264
# iter=199975  val=0.8568  norm_vF=0.0000  norm_Axb=0.0023  norm_T=5.4644
# iter=199976  val=0.8653  norm_vF=0.0003  norm_Axb=0.0074  norm_T=5.8738
# iter=199977  val=0.8575  norm_vF=0.0000  norm_Axb=0.0017  norm_T=5.4606
# iter=199978  val=0.8659  norm_vF=0.0001  norm_Axb=0.0081  norm_T=5.4262
# iter=199979  val=0.8587  norm_vF=0.0000  norm_Axb=0.0003  norm_T=5.4539
# iter=199980  val=0.8672  norm_vF=0.0007  norm_Axb=0.0095  norm_T=5.7984
# iter=199981  val=0.8592  norm_vF=0.0000  norm_Axb=0.0003  norm_T=3.3331
# iter=199982  val=0.8507  norm_vF=0.0000  norm_Axb=0.0094  norm_T=5.4979
# iter=199983  val=0.8591  norm_vF=0.0000  norm_Axb=0.0003  norm_T=4.7059
# iter=199984  val=0.8523  norm_vF=0.0000  norm_Axb=0.0077  norm_T=5.4894
# iter=199985  val=0.8607  norm_vF=0.0000  norm_Axb=0.0021  norm_T=3.3418
# iter=199986  val=0.8522  norm_vF=0.0000  norm_Axb=0.0076  norm_T=5.4893
# iter=199987  val=0.8606  norm_vF=0.0000  norm_Axb=0.0021  norm_T=3.3417
# iter=199988  val=0.8521  norm_vF=0.0000  norm_Axb=0.0076  norm_T=5.4892
# iter=199989  val=0.8605  norm_vF=0.0000  norm_Axb=0.0022  norm_T=3.3415
# iter=199990  val=0.8520  norm_vF=0.0000  norm_Axb=0.0076  norm_T=5.4891
# iter=199991  val=0.8604  norm_vF=0.0002  norm_Axb=0.0022  norm_T=4.9082
# iter=199992  val=0.8534  norm_vF=0.0000  norm_Axb=0.0062  norm_T=5.4817
# iter=199993  val=0.8618  norm_vF=0.0002  norm_Axb=0.0036  norm_T=4.9530
# iter=199994  val=0.8548  norm_vF=0.0000  norm_Axb=0.0046  norm_T=5.4744
# iter=199995  val=0.8632  norm_vF=0.0004  norm_Axb=0.0052  norm_T=5.1411
# iter=199996  val=0.8560  norm_vF=0.0000  norm_Axb=0.0033  norm_T=5.4687
# iter=199997  val=0.8644  norm_vF=0.0003  norm_Axb=0.0065  norm_T=5.6178
# iter=199998  val=0.8569  norm_vF=0.0000  norm_Axb=0.0023  norm_T=5.4632
# iter=199999  val=0.8653  norm_vF=0.0001  norm_Axb=0.0075  norm_T=5.6560
# iter=200000  val=0.8575  norm_vF=0.0000  norm_Axb=0.0015  norm_T=5.4605
# WARNING: replacing module ClassificationModels.

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_test()
# Out:
# Class 1
# WARNING: replacing module ClassificationModels.
# iter=951  val=0.8482  norm_vF=0.0000  norm_Axb=0.0372  norm_T=4.1465
# iter=952  val=0.9211  norm_vF=0.0189  norm_Axb=0.0677  norm_T=4.8325
# iter=953  val=0.8471  norm_vF=0.0000  norm_Axb=0.0335  norm_T=4.1518
# iter=954  val=0.9197  norm_vF=0.0160  norm_Axb=0.0713  norm_T=4.8285
# iter=955  val=0.8459  norm_vF=0.0062  norm_Axb=0.0300  norm_T=4.1108
# iter=956  val=0.9177  norm_vF=0.0135  norm_Axb=0.0586  norm_T=4.8205
# iter=957  val=0.8442  norm_vF=0.0000  norm_Axb=0.0426  norm_T=4.1623
# iter=958  val=0.9164  norm_vF=0.0107  norm_Axb=0.0620  norm_T=4.8072
# iter=959  val=0.8433  norm_vF=0.0055  norm_Axb=0.0391  norm_T=4.1211
# iter=960  val=0.9144  norm_vF=0.0081  norm_Axb=0.0494  norm_T=4.8050
# iter=961  val=0.8415  norm_vF=0.0000  norm_Axb=0.0517  norm_T=4.1729
# iter=962  val=0.9131  norm_vF=0.0058  norm_Axb=0.0528  norm_T=4.2932
# iter=963  val=0.8467  norm_vF=0.0000  norm_Axb=0.0392  norm_T=4.1491
# iter=964  val=0.9191  norm_vF=0.0192  norm_Axb=0.0650  norm_T=4.7678
# iter=965  val=0.8464  norm_vF=0.0000  norm_Axb=0.0342  norm_T=4.1515
# iter=966  val=0.9186  norm_vF=0.0157  norm_Axb=0.0699  norm_T=4.8220
# iter=967  val=0.8454  norm_vF=0.0064  norm_Axb=0.0306  norm_T=4.1020
# iter=968  val=0.9167  norm_vF=0.0131  norm_Axb=0.0575  norm_T=4.8202
# iter=969  val=0.8438  norm_vF=0.0000  norm_Axb=0.0430  norm_T=4.1616
# iter=970  val=0.9154  norm_vF=0.0103  norm_Axb=0.0609  norm_T=4.8041
# iter=971  val=0.8429  norm_vF=0.0057  norm_Axb=0.0395  norm_T=4.1196
# iter=972  val=0.9135  norm_vF=0.0078  norm_Axb=0.0484  norm_T=4.8045
# iter=973  val=0.8411  norm_vF=0.0000  norm_Axb=0.0520  norm_T=4.1721
# iter=974  val=0.9123  norm_vF=0.0059  norm_Axb=0.0517  norm_T=4.2133
# iter=975  val=0.8473  norm_vF=0.0000  norm_Axb=0.0380  norm_T=4.1440
# iter=976  val=0.9193  norm_vF=0.0193  norm_Axb=0.0656  norm_T=4.8216
# iter=977  val=0.8464  norm_vF=0.0000  norm_Axb=0.0341  norm_T=4.1488
# iter=978  val=0.9181  norm_vF=0.0163  norm_Axb=0.0694  norm_T=4.8283
# iter=979  val=0.8453  norm_vF=0.0054  norm_Axb=0.0306  norm_T=4.1059
# iter=980  val=0.9161  norm_vF=0.0138  norm_Axb=0.0569  norm_T=4.8215
# iter=981  val=0.8437  norm_vF=0.0000  norm_Axb=0.0430  norm_T=4.1592
# iter=982  val=0.9149  norm_vF=0.0110  norm_Axb=0.0603  norm_T=4.8098
# iter=983  val=0.8427  norm_vF=0.0047  norm_Axb=0.0396  norm_T=4.1196
# iter=984  val=0.9129  norm_vF=0.0084  norm_Axb=0.0478  norm_T=4.8058
# iter=985  val=0.8410  norm_vF=0.0000  norm_Axb=0.0520  norm_T=4.1697
# iter=986  val=0.9117  norm_vF=0.0057  norm_Axb=0.0511  norm_T=4.7480
# iter=987  val=0.8407  norm_vF=0.0035  norm_Axb=0.0479  norm_T=4.0931
# iter=988  val=0.9102  norm_vF=0.0035  norm_Axb=0.0391  norm_T=4.7942
# iter=989  val=0.8389  norm_vF=0.0000  norm_Axb=0.0604  norm_T=4.1793
# iter=990  val=0.9091  norm_vF=0.0036  norm_Axb=0.0425  norm_T=4.1852
# iter=991  val=0.8453  norm_vF=0.0000  norm_Axb=0.0459  norm_T=4.1512
# iter=992  val=0.9164  norm_vF=0.0151  norm_Axb=0.0569  norm_T=4.8209
# iter=993  val=0.8443  norm_vF=0.0000  norm_Axb=0.0423  norm_T=4.1565
# iter=994  val=0.9152  norm_vF=0.0123  norm_Axb=0.0604  norm_T=4.8172
# iter=995  val=0.8433  norm_vF=0.0026  norm_Axb=0.0389  norm_T=4.1167
# iter=996  val=0.9133  norm_vF=0.0097  norm_Axb=0.0480  norm_T=4.8095
# iter=997  val=0.8417  norm_vF=0.0000  norm_Axb=0.0512  norm_T=4.1672
# iter=998  val=0.9121  norm_vF=0.0070  norm_Axb=0.0513  norm_T=4.7967
# iter=999  val=0.8409  norm_vF=0.0019  norm_Axb=0.0477  norm_T=4.1271
# iter=1000  val=0.9102  norm_vF=0.0044  norm_Axb=0.0390  norm_T=4.7945
# ------------
# Class 2
#
# iter=951  val=1.0689  norm_vF=0.0129  norm_Axb=0.0570  norm_T=4.4668
# iter=952  val=0.9882  norm_vF=0.0000  norm_Axb=0.0437  norm_T=3.8950
# iter=953  val=1.0673  norm_vF=0.0097  norm_Axb=0.0609  norm_T=4.4833
# iter=954  val=0.9867  norm_vF=0.0065  norm_Axb=0.0402  norm_T=3.7246
# iter=955  val=1.0676  norm_vF=0.0075  norm_Axb=0.0526  norm_T=4.5008
# iter=956  val=0.9869  norm_vF=0.0000  norm_Axb=0.0486  norm_T=3.8997
# iter=957  val=1.0656  norm_vF=0.0095  norm_Axb=0.0558  norm_T=4.1270
# iter=958  val=0.9887  norm_vF=0.0000  norm_Axb=0.0401  norm_T=3.8910
# iter=959  val=1.0677  norm_vF=0.0176  norm_Axb=0.0642  norm_T=4.5030
# iter=960  val=0.9870  norm_vF=0.0010  norm_Axb=0.0367  norm_T=3.7329
# iter=961  val=1.0678  norm_vF=0.0153  norm_Axb=0.0559  norm_T=4.5043
# iter=962  val=0.9872  norm_vF=0.0000  norm_Axb=0.0450  norm_T=3.8956
# iter=963  val=1.0659  norm_vF=0.0120  norm_Axb=0.0591  norm_T=4.4970
# iter=964  val=0.9856  norm_vF=0.0032  norm_Axb=0.0416  norm_T=3.7380
# iter=965  val=1.0661  norm_vF=0.0097  norm_Axb=0.0508  norm_T=4.4978
# iter=966  val=0.9859  norm_vF=0.0000  norm_Axb=0.0498  norm_T=3.9005
# iter=967  val=1.0642  norm_vF=0.0065  norm_Axb=0.0540  norm_T=4.4166
# iter=968  val=0.9850  norm_vF=0.0045  norm_Axb=0.0455  norm_T=3.6721
# iter=969  val=1.0652  norm_vF=0.0048  norm_Axb=0.0465  norm_T=4.4932
# iter=970  val=0.9853  norm_vF=0.0000  norm_Axb=0.0539  norm_T=3.9037
# iter=971  val=1.0633  norm_vF=0.0075  norm_Axb=0.0497  norm_T=4.1214
# iter=972  val=0.9872  norm_vF=0.0000  norm_Axb=0.0454  norm_T=3.8953
# iter=973  val=1.0654  norm_vF=0.0148  norm_Axb=0.0581  norm_T=4.4953
# iter=974  val=0.9856  norm_vF=0.0000  norm_Axb=0.0421  norm_T=3.8999
# iter=975  val=1.0636  norm_vF=0.0116  norm_Axb=0.0614  norm_T=4.4867
# iter=976  val=0.9841  norm_vF=0.0099  norm_Axb=0.0387  norm_T=3.7405
# iter=977  val=1.0639  norm_vF=0.0092  norm_Axb=0.0532  norm_T=4.4909
# iter=978  val=0.9844  norm_vF=0.0011  norm_Axb=0.0468  norm_T=3.7419
# iter=979  val=1.0641  norm_vF=0.0068  norm_Axb=0.0450  norm_T=4.4915
# iter=980  val=0.9847  norm_vF=0.0000  norm_Axb=0.0549  norm_T=3.9044
# iter=981  val=1.0623  norm_vF=0.0042  norm_Axb=0.0482  norm_T=4.1326
# iter=982  val=0.9865  norm_vF=0.0000  norm_Axb=0.0467  norm_T=3.8961
# iter=983  val=1.0643  norm_vF=0.0167  norm_Axb=0.0563  norm_T=4.4846
# iter=984  val=0.9851  norm_vF=0.0000  norm_Axb=0.0431  norm_T=3.9006
# iter=985  val=1.0626  norm_vF=0.0133  norm_Axb=0.0598  norm_T=4.4865
# iter=986  val=0.9836  norm_vF=0.0069  norm_Axb=0.0397  norm_T=3.7409
# iter=987  val=1.0630  norm_vF=0.0109  norm_Axb=0.0517  norm_T=4.4887
# iter=988  val=0.9840  norm_vF=0.0000  norm_Axb=0.0477  norm_T=3.9046
# iter=989  val=1.0613  norm_vF=0.0100  norm_Axb=0.0550  norm_T=4.1199
# iter=990  val=0.9859  norm_vF=0.0018  norm_Axb=0.0393  norm_T=3.1513
# iter=991  val=1.0675  norm_vF=0.0056  norm_Axb=0.0520  norm_T=4.1779
# iter=992  val=0.9913  norm_vF=0.0000  norm_Axb=0.0430  norm_T=3.8849
# iter=993  val=1.0689  norm_vF=0.0138  norm_Axb=0.0594  norm_T=4.4803
# iter=994  val=0.9898  norm_vF=0.0000  norm_Axb=0.0393  norm_T=3.8891
# iter=995  val=1.0672  norm_vF=0.0110  norm_Axb=0.0631  norm_T=4.4414
# iter=996  val=0.9887  norm_vF=0.0077  norm_Axb=0.0353  norm_T=3.6767
# iter=997  val=1.0679  norm_vF=0.0091  norm_Axb=0.0554  norm_T=4.5036
# iter=998  val=0.9888  norm_vF=0.0000  norm_Axb=0.0436  norm_T=3.8922
# iter=999  val=1.0660  norm_vF=0.0107  norm_Axb=0.0585  norm_T=4.1348
# iter=1000  val=0.9905  norm_vF=0.0002  norm_Axb=0.0354  norm_T=3.1360
# ------------
# Accuracy on test set of MLE: 0.875
#
# ==========================
#
# Class 1
#
# ------------
# Class 2
#
# ------------
# Accuracy on test set of Christoffel function: 0.875

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_Iris_MLE()
# Out:
# Class 1
# WARNING: replacing module ClassificationModels.
# iter=1  val=0.3005  norm_vF=0.5940  norm_Axb=2.8386  norm_T=3.7198
# iter=2  val=-0.2926  norm_vF=0.3462  norm_Axb=0.8815  norm_T=4.4912
# iter=3  val=-0.6762  norm_vF=0.1529  norm_Axb=2.2592  norm_T=9.2691
# iter=4  val=-0.3670  norm_vF=0.2555  norm_Axb=0.5347  norm_T=4.4174
# iter=5  val=-0.6545  norm_vF=0.1955  norm_Axb=1.9241  norm_T=9.5305
# iter=6  val=-0.3986  norm_vF=0.2470  norm_Axb=0.4043  norm_T=3.7589
# iter=7  val=-0.6400  norm_vF=0.1397  norm_Axb=1.2881  norm_T=9.6574
# iter=8  val=-0.4155  norm_vF=0.3337  norm_Axb=0.7538  norm_T=4.2938
# iter=9  val=-0.6251  norm_vF=0.1550  norm_Axb=1.0774  norm_T=9.5600
# iter=10  val=-0.4236  norm_vF=0.3056  norm_Axb=0.7514  norm_T=4.3209
# iter=11  val=-0.6209  norm_vF=0.1248  norm_Axb=0.9582  norm_T=9.4497
# iter=12  val=-0.4379  norm_vF=0.2762  norm_Axb=0.7111  norm_T=4.6958
# iter=13  val=-0.6143  norm_vF=0.1393  norm_Axb=0.8704  norm_T=9.3658
# iter=14  val=-0.4451  norm_vF=0.2621  norm_Axb=0.6746  norm_T=4.5924
# iter=15  val=-0.6148  norm_vF=0.1210  norm_Axb=0.8062  norm_T=9.2881
# iter=16  val=-0.4579  norm_vF=0.2405  norm_Axb=0.6383  norm_T=4.9169
# iter=17  val=-0.6129  norm_vF=0.1315  norm_Axb=0.7581  norm_T=9.2263
# iter=18  val=-0.4652  norm_vF=0.2306  norm_Axb=0.6033  norm_T=4.7817
# iter=19  val=-0.6155  norm_vF=0.1433  norm_Axb=0.7214  norm_T=9.1712
# iter=20  val=-0.4763  norm_vF=0.2133  norm_Axb=0.5695  norm_T=5.0744
# iter=21  val=-0.6154  norm_vF=0.1416  norm_Axb=0.6942  norm_T=9.3415
# iter=22  val=-0.4867  norm_vF=0.2015  norm_Axb=0.5354  norm_T=4.9141
# iter=23  val=-0.6219  norm_vF=0.1401  norm_Axb=0.6738  norm_T=9.0976
# iter=24  val=-0.4969  norm_vF=0.1867  norm_Axb=0.5033  norm_T=5.1813
# iter=25  val=-0.6231  norm_vF=0.1500  norm_Axb=0.6594  norm_T=9.0706
# iter=26  val=-0.5033  norm_vF=0.1802  norm_Axb=0.4713  norm_T=5.0017
# iter=27  val=-0.6270  norm_vF=0.1600  norm_Axb=0.6481  norm_T=9.0509
# iter=28  val=-0.5122  norm_vF=0.1672  norm_Axb=0.4410  norm_T=5.2544
# iter=29  val=-0.6285  norm_vF=0.1382  norm_Axb=0.6413  norm_T=9.0417
# iter=30  val=-0.5183  norm_vF=0.1616  norm_Axb=0.4105  norm_T=5.0560
# iter=31  val=-0.6328  norm_vF=0.1480  norm_Axb=0.6363  norm_T=9.0341
# iter=32  val=-0.5265  norm_vF=0.1685  norm_Axb=0.3819  norm_T=4.3895
# iter=33  val=-0.6317  norm_vF=0.1291  norm_Axb=0.4554  norm_T=9.2699
# iter=34  val=-0.5315  norm_vF=0.2058  norm_Axb=0.5328  norm_T=5.2537
# iter=35  val=-0.6354  norm_vF=0.1324  norm_Axb=0.4339  norm_T=8.9680
# iter=36  val=-0.5360  norm_vF=0.1988  norm_Axb=0.5262  norm_T=5.1921
# iter=37  val=-0.6392  norm_vF=0.1428  norm_Axb=0.4309  norm_T=8.9135
# iter=38  val=-0.5427  norm_vF=0.1891  norm_Axb=0.5031  norm_T=5.4800
# iter=39  val=-0.6409  norm_vF=0.1400  norm_Axb=0.4311  norm_T=9.0750
# iter=40  val=-0.5496  norm_vF=0.1824  norm_Axb=0.4783  norm_T=5.2948
# iter=41  val=-0.6468  norm_vF=0.1379  norm_Axb=0.4330  norm_T=9.1084
# iter=42  val=-0.5589  norm_vF=0.1696  norm_Axb=0.4541  norm_T=5.5671
# iter=43  val=-0.6513  norm_vF=0.1383  norm_Axb=0.4371  norm_T=8.8234
# iter=44  val=-0.5634  norm_vF=0.1659  norm_Axb=0.4293  norm_T=5.4887
# iter=45  val=-0.6532  norm_vF=0.1503  norm_Axb=0.4286  norm_T=8.7944
# iter=46  val=-0.5673  norm_vF=0.1628  norm_Axb=0.4185  norm_T=4.6553
# iter=47  val=-0.6527  norm_vF=0.1231  norm_Axb=0.2960  norm_T=9.0566
# iter=48  val=-0.5716  norm_vF=0.2037  norm_Axb=0.5274  norm_T=5.4608
# iter=49  val=-0.6587  norm_vF=0.1306  norm_Axb=0.3064  norm_T=8.7078
# iter=50  val=-0.5770  norm_vF=0.1956  norm_Axb=0.5056  norm_T=5.7372
#
# Class 2
#
# iter=1  val=0.7521  norm_vF=0.4389  norm_Axb=2.1320  norm_T=3.5169
# iter=2  val=-0.1406  norm_vF=0.1942  norm_Axb=0.3072  norm_T=10.2179
# iter=3  val=0.6098  norm_vF=0.5734  norm_Axb=3.0533  norm_T=5.6602
# iter=4  val=-0.0622  norm_vF=0.2835  norm_Axb=0.7239  norm_T=5.1294
# iter=5  val=-0.4239  norm_vF=0.2362  norm_Axb=1.7690  norm_T=8.7599
# iter=6  val=-0.1001  norm_vF=0.2844  norm_Axb=0.5500  norm_T=4.3124
# iter=7  val=-0.4039  norm_vF=0.1684  norm_Axb=1.2956  norm_T=8.8612
# iter=8  val=-0.1201  norm_vF=0.3135  norm_Axb=0.7339  norm_T=4.9406
# iter=9  val=-0.3933  norm_vF=0.1902  norm_Axb=1.1740  norm_T=8.8521
# iter=10  val=-0.1401  norm_vF=0.2736  norm_Axb=0.6435  norm_T=5.0088
# iter=11  val=-0.3870  norm_vF=0.1431  norm_Axb=1.0932  norm_T=9.0052
# iter=12  val=-0.1620  norm_vF=0.2371  norm_Axb=0.5658  norm_T=5.0497
# iter=13  val=-0.3880  norm_vF=0.1664  norm_Axb=1.0386  norm_T=8.8770
# iter=14  val=-0.1769  norm_vF=0.2097  norm_Axb=0.4991  norm_T=5.0627
# iter=15  val=-0.3863  norm_vF=0.1889  norm_Axb=0.9992  norm_T=8.9064
# iter=16  val=-0.1897  norm_vF=0.2115  norm_Axb=0.4397  norm_T=4.3040
# iter=17  val=-0.3740  norm_vF=0.1447  norm_Axb=0.7313  norm_T=8.8911
# iter=18  val=-0.1867  norm_vF=0.2573  norm_Axb=0.6289  norm_T=5.1367
# iter=19  val=-0.3729  norm_vF=0.1633  norm_Axb=0.7002  norm_T=8.8403
# iter=20  val=-0.1963  norm_vF=0.2396  norm_Axb=0.5892  norm_T=5.3690
# iter=21  val=-0.3699  norm_vF=0.1281  norm_Axb=0.6653  norm_T=8.9355
# iter=22  val=-0.2051  norm_vF=0.2261  norm_Axb=0.5626  norm_T=5.2841
# iter=23  val=-0.3746  norm_vF=0.1443  norm_Axb=0.6513  norm_T=8.7675
# iter=24  val=-0.2149  norm_vF=0.2120  norm_Axb=0.5247  norm_T=5.3304
# iter=25  val=-0.3766  norm_vF=0.1615  norm_Axb=0.6419  norm_T=8.7443
# iter=26  val=-0.2242  norm_vF=0.1989  norm_Axb=0.4874  norm_T=5.5104
# iter=27  val=-0.3761  norm_vF=0.1588  norm_Axb=0.6256  norm_T=8.7304
# iter=28  val=-0.2300  norm_vF=0.1910  norm_Axb=0.4621  norm_T=5.3996
# iter=29  val=-0.3792  norm_vF=0.1427  norm_Axb=0.6239  norm_T=8.7184
# iter=30  val=-0.2386  norm_vF=0.1796  norm_Axb=0.4266  norm_T=5.5576
# iter=31  val=-0.3799  norm_vF=0.1585  norm_Axb=0.6136  norm_T=8.7149
# iter=32  val=-0.2440  norm_vF=0.1728  norm_Axb=0.4034  norm_T=5.4402
# iter=33  val=-0.3831  norm_vF=0.1549  norm_Axb=0.6166  norm_T=8.7179
# iter=34  val=-0.2524  norm_vF=0.1626  norm_Axb=0.3696  norm_T=5.4448
# iter=35  val=-0.3866  norm_vF=0.1416  norm_Axb=0.6214  norm_T=8.9882
# iter=36  val=-0.2639  norm_vF=0.1648  norm_Axb=0.3363  norm_T=4.5618
# iter=37  val=-0.3821  norm_vF=0.1514  norm_Axb=0.4729  norm_T=8.7089
# iter=38  val=-0.2584  norm_vF=0.1973  norm_Axb=0.4605  norm_T=5.4808
# iter=39  val=-0.3849  norm_vF=0.1495  norm_Axb=0.4768  norm_T=8.8179
# iter=40  val=-0.2676  norm_vF=0.1863  norm_Axb=0.4316  norm_T=5.5272
# iter=41  val=-0.3909  norm_vF=0.1609  norm_Axb=0.4836  norm_T=8.6738
# iter=42  val=-0.2751  norm_vF=0.1781  norm_Axb=0.4031  norm_T=5.5419
# iter=43  val=-0.3944  norm_vF=0.1544  norm_Axb=0.4911  norm_T=8.9275
# iter=44  val=-0.2850  norm_vF=0.1690  norm_Axb=0.3745  norm_T=4.6397
# iter=45  val=-0.3906  norm_vF=0.1445  norm_Axb=0.3608  norm_T=8.9023
# iter=46  val=-0.2834  norm_vF=0.2058  norm_Axb=0.4860  norm_T=5.6030
# iter=47  val=-0.3964  norm_vF=0.1526  norm_Axb=0.3682  norm_T=8.5989
# iter=48  val=-0.2891  norm_vF=0.1981  norm_Axb=0.4607  norm_T=5.7633
# iter=49  val=-0.3976  norm_vF=0.1422  norm_Axb=0.3660  norm_T=8.5686
# iter=50  val=-0.2924  norm_vF=0.1932  norm_Axb=0.4459  norm_T=5.8036
#
# Class 3
#
# iter=1  val=0.3908  norm_vF=0.5549  norm_Axb=2.6005  norm_T=3.5874
# iter=2  val=-0.2782  norm_vF=0.3008  norm_Axb=0.5049  norm_T=4.1793
# iter=3  val=-0.6628  norm_vF=0.1590  norm_Axb=2.6341  norm_T=9.8409
# iter=4  val=-0.3422  norm_vF=0.2274  norm_Axb=0.1545  norm_T=3.3880
# iter=5  val=-0.6250  norm_vF=0.1936  norm_Axb=1.6372  norm_T=10.2223
# iter=6  val=-0.3499  norm_vF=0.3625  norm_Axb=0.7198  norm_T=3.6907
# iter=7  val=-0.5915  norm_vF=0.1530  norm_Axb=1.2863  norm_T=10.1047
# iter=8  val=-0.3481  norm_vF=0.3245  norm_Axb=0.7621  norm_T=3.9933
# iter=9  val=-0.5692  norm_vF=0.1856  norm_Axb=1.0783  norm_T=9.9592
# iter=10  val=-0.3486  norm_vF=0.3014  norm_Axb=0.7554  norm_T=3.9838
# iter=11  val=-0.5608  norm_vF=0.1480  norm_Axb=0.9391  norm_T=9.8078
# iter=12  val=-0.3597  norm_vF=0.2720  norm_Axb=0.7346  norm_T=4.3841
# iter=13  val=-0.5514  norm_vF=0.1778  norm_Axb=0.8344  norm_T=9.6869
# iter=14  val=-0.3654  norm_vF=0.2589  norm_Axb=0.7142  norm_T=4.3383
# iter=15  val=-0.5500  norm_vF=0.1406  norm_Axb=0.7582  norm_T=9.5676
# iter=16  val=-0.3770  norm_vF=0.2382  norm_Axb=0.6895  norm_T=4.4824
# iter=17  val=-0.5502  norm_vF=0.1633  norm_Axb=0.7003  norm_T=9.4618
# iter=18  val=-0.3876  norm_vF=0.2209  norm_Axb=0.6638  norm_T=4.8358
# iter=19  val=-0.5476  norm_vF=0.1473  norm_Axb=0.6525  norm_T=9.3770
# iter=20  val=-0.3939  norm_vF=0.2134  norm_Axb=0.6408  norm_T=4.7142
# iter=21  val=-0.5498  norm_vF=0.1494  norm_Axb=0.6183  norm_T=9.2951
# iter=22  val=-0.4041  norm_vF=0.1991  norm_Axb=0.6139  norm_T=5.0318
# iter=23  val=-0.5495  norm_vF=0.1676  norm_Axb=0.5904  norm_T=9.2313
# iter=24  val=-0.4109  norm_vF=0.1933  norm_Axb=0.5883  norm_T=4.8924
# iter=25  val=-0.5531  norm_vF=0.1571  norm_Axb=0.5710  norm_T=9.3907
# iter=26  val=-0.4242  norm_vF=0.1794  norm_Axb=0.5602  norm_T=4.3081
# iter=27  val=-0.5520  norm_vF=0.1498  norm_Axb=0.3481  norm_T=9.0809
# iter=28  val=-0.4243  norm_vF=0.2463  norm_Axb=0.7429  norm_T=5.1022
# iter=29  val=-0.5548  norm_vF=0.1649  norm_Axb=0.3311  norm_T=8.9711
# iter=30  val=-0.4326  norm_vF=0.2360  norm_Axb=0.7213  norm_T=5.2253
# iter=31  val=-0.5584  norm_vF=0.1350  norm_Axb=0.3199  norm_T=9.1334
# iter=32  val=-0.4441  norm_vF=0.2220  norm_Axb=0.6976  norm_T=5.5504
# iter=33  val=-0.5631  norm_vF=0.1477  norm_Axb=0.3135  norm_T=8.7816
# iter=34  val=-0.4497  norm_vF=0.2185  norm_Axb=0.6731  norm_T=5.4309
# iter=35  val=-0.5669  norm_vF=0.1603  norm_Axb=0.3107  norm_T=8.7017
# iter=36  val=-0.4576  norm_vF=0.2095  norm_Axb=0.6469  norm_T=5.7377
# iter=37  val=-0.5695  norm_vF=0.1391  norm_Axb=0.3114  norm_T=8.8518
# iter=38  val=-0.4665  norm_vF=0.2028  norm_Axb=0.6193  norm_T=5.5986
# iter=39  val=-0.5764  norm_vF=0.1484  norm_Axb=0.3153  norm_T=8.5698
# iter=40  val=-0.4740  norm_vF=0.1944  norm_Axb=0.5914  norm_T=5.8844
# iter=41  val=-0.5792  norm_vF=0.1552  norm_Axb=0.3214  norm_T=8.5132
# iter=42  val=-0.4797  norm_vF=0.1912  norm_Axb=0.5628  norm_T=5.7282
# iter=43  val=-0.5834  norm_vF=0.1652  norm_Axb=0.3294  norm_T=8.4668
# iter=44  val=-0.4871  norm_vF=0.1832  norm_Axb=0.5335  norm_T=5.9994
# iter=45  val=-0.5866  norm_vF=0.1497  norm_Axb=0.3396  norm_T=8.6954
# iter=46  val=-0.4957  norm_vF=0.1762  norm_Axb=0.5036  norm_T=5.9376
# iter=47  val=-0.5918  norm_vF=0.1520  norm_Axb=0.3403  norm_T=8.3940
# iter=48  val=-0.5005  norm_vF=0.1710  norm_Axb=0.4848  norm_T=6.0843
# iter=49  val=-0.5949  norm_vF=0.1584  norm_Axb=0.3531  norm_T=8.3639
# iter=50  val=-0.5057  norm_vF=0.1764  norm_Axb=0.4550  norm_T=4.7852
#
#   0.313322 seconds (359.43 k allocations: 49.831 MiB)
# Accuracy: 1.0

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_optdigits_Christoffel()
# Out:
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# Class 1
# WARNING: replacing module ClassificationModels.
# Class 2
#
# Class 3
#
# Class 4
#
# Class 5
#
# Class 6
#
# Class 7
#
# Class 8
#
# Class 9
#
# Class 10
#
# Accuracy: 0.9934296977660972

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_optdigits_MLE()

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_optdigits_MLE_arb_basis()
# Out:
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# largest_rr=1953
# Class 1
#
# iter=
# WARNING: replacing module ClassificationModels.
# 0  val=-1.1777  norm_vF=0.0000  norm_Axb=0.9778  norm_T=1.4010
# iter=1  val=-1.7192  norm_vF=0.0000  norm_Axb=0.9620  norm_T=1.1342
# iter=2  val=-1.9165  norm_vF=0.0000  norm_Axb=0.9519  norm_T=1.0822
# iter=3  val=-2.0386  norm_vF=0.0000  norm_Axb=0.9431  norm_T=1.0574
# iter=4  val=-2.1276  norm_vF=0.0000  norm_Axb=0.9347  norm_T=1.0422
# iter=5  val=-2.1980  norm_vF=0.0000  norm_Axb=0.9266  norm_T=1.0316
# iter=6  val=-2.2564  norm_vF=0.0000  norm_Axb=0.9186  norm_T=1.0235
# iter=7  val=-2.3066  norm_vF=0.0000  norm_Axb=0.9108  norm_T=1.0172
# iter=8  val=-2.3506  norm_vF=0.0000  norm_Axb=0.9029  norm_T=1.0119
# iter=9  val=-2.3899  norm_vF=0.0000  norm_Axb=0.8951  norm_T=1.0075
# iter=10  val=-2.4254  norm_vF=0.0000  norm_Axb=0.8873  norm_T=1.0037
# Class 2
#
# iter=0  val=-1.1937  norm_vF=0.0000  norm_Axb=0.9784  norm_T=1.4082
# iter=1  val=-1.7407  norm_vF=0.0000  norm_Axb=0.9624  norm_T=1.1356
# iter=2  val=-1.9390  norm_vF=0.0000  norm_Axb=0.9522  norm_T=1.0830
# iter=3  val=-2.0616  norm_vF=0.0000  norm_Axb=0.9434  norm_T=1.0581
# iter=4  val=-2.1509  norm_vF=0.0000  norm_Axb=0.9350  norm_T=1.0428
# iter=5  val=-2.2215  norm_vF=0.0000  norm_Axb=0.9269  norm_T=1.0320
# iter=6  val=-2.2801  norm_vF=0.0000  norm_Axb=0.9189  norm_T=1.0240
# iter=7  val=-2.3303  norm_vF=0.0000  norm_Axb=0.9110  norm_T=1.0176
# iter=8  val=-2.3744  norm_vF=0.0000  norm_Axb=0.9031  norm_T=1.0123
# iter=9  val=-2.4138  norm_vF=0.0000  norm_Axb=0.8953  norm_T=1.0078
# iter=10  val=-2.4495  norm_vF=0.0000  norm_Axb=0.8875  norm_T=1.0040
# Class 3
#
# iter=0  val=-1.1671  norm_vF=0.0000  norm_Axb=0.9775  norm_T=1.3999
# iter=1  val=-1.7080  norm_vF=0.0000  norm_Axb=0.9611  norm_T=1.1336
# iter=2  val=-1.9053  norm_vF=0.0000  norm_Axb=0.9509  norm_T=1.0815
# iter=3  val=-2.0276  norm_vF=0.0000  norm_Axb=0.9419  norm_T=1.0567
# iter=4  val=-2.1167  norm_vF=0.0000  norm_Axb=0.9334  norm_T=1.0414
# iter=5  val=-2.1873  norm_vF=0.0000  norm_Axb=0.9252  norm_T=1.0307
# iter=6  val=-2.2459  norm_vF=0.0000  norm_Axb=0.9171  norm_T=1.0226
# iter=7  val=-2.2961  norm_vF=0.0000  norm_Axb=0.9092  norm_T=1.0162
# iter=8  val=-2.3403  norm_vF=0.0000  norm_Axb=0.9013  norm_T=1.0109
# iter=9  val=-2.3797  norm_vF=0.0000  norm_Axb=0.8934  norm_T=1.0065
# iter=10  val=-2.4155  norm_vF=0.0000  norm_Axb=0.8856  norm_T=1.0026
# Class 4
#
# iter=0  val=-1.1652  norm_vF=0.0000  norm_Axb=0.9775  norm_T=1.3996
# iter=1  val=-1.7057  norm_vF=0.0000  norm_Axb=0.9613  norm_T=1.1337
# iter=2  val=-1.9030  norm_vF=0.0000  norm_Axb=0.9511  norm_T=1.0816
# iter=3  val=-2.0251  norm_vF=0.0000  norm_Axb=0.9422  norm_T=1.0568
# iter=4  val=-2.1142  norm_vF=0.0000  norm_Axb=0.9338  norm_T=1.0416
# iter=5  val=-2.1847  norm_vF=0.0000  norm_Axb=0.9256  norm_T=1.0309
# iter=6  val=-2.2433  norm_vF=0.0000  norm_Axb=0.9175  norm_T=1.0228
# iter=7  val=-2.2935  norm_vF=0.0000  norm_Axb=0.9096  norm_T=1.0164
# iter=8  val=-2.3376  norm_vF=0.0000  norm_Axb=0.9017  norm_T=1.0112
# iter=9  val=-2.3770  norm_vF=0.0000  norm_Axb=0.8939  norm_T=1.0067
# iter=10  val=-2.4127  norm_vF=0.0000  norm_Axb=0.8861  norm_T=1.0029
# Class 5
#
# iter=0  val=-1.1102  norm_vF=0.0000  norm_Axb=0.9766  norm_T=1.4084
# iter=1  val=-1.6584  norm_vF=0.0000  norm_Axb=0.9591  norm_T=1.1333
# iter=2  val=-1.8572  norm_vF=0.0000  norm_Axb=0.9482  norm_T=1.0802
# iter=3  val=-1.9803  norm_vF=0.0000  norm_Axb=0.9389  norm_T=1.0550
# iter=4  val=-2.0701  norm_vF=0.0000  norm_Axb=0.9301  norm_T=1.0395
# iter=5  val=-2.1412  norm_vF=0.0000  norm_Axb=0.9216  norm_T=1.0285
# iter=6  val=-2.2004  norm_vF=0.0000  norm_Axb=0.9134  norm_T=1.0203
# iter=7  val=-2.2511  norm_vF=0.0000  norm_Axb=0.9052  norm_T=1.0137
# iter=8  val=-2.2957  norm_vF=0.0000  norm_Axb=0.8972  norm_T=1.0083
# iter=9  val=-2.3356  norm_vF=0.0000  norm_Axb=0.8891  norm_T=1.0038
# iter=10  val=-2.3717  norm_vF=0.0000  norm_Axb=0.8812  norm_T=0.9998
# Class 6
#
# iter=0  val=-1.1295  norm_vF=0.0000  norm_Axb=0.9767  norm_T=1.4003
# iter=1  val=-1.6712  norm_vF=0.0000  norm_Axb=0.9599  norm_T=1.1329
# iter=2  val=-1.8689  norm_vF=0.0000  norm_Axb=0.9494  norm_T=1.0805
# iter=3  val=-1.9914  norm_vF=0.0000  norm_Axb=0.9402  norm_T=1.0556
# iter=4  val=-2.0808  norm_vF=0.0000  norm_Axb=0.9316  norm_T=1.0402
# iter=5  val=-2.1516  norm_vF=0.0000  norm_Axb=0.9232  norm_T=1.0294
# iter=6  val=-2.2104  norm_vF=0.0000  norm_Axb=0.9151  norm_T=1.0213
# iter=7  val=-2.2609  norm_vF=0.0000  norm_Axb=0.9070  norm_T=1.0148
# iter=8  val=-2.3053  norm_vF=0.0000  norm_Axb=0.8990  norm_T=1.0095
# iter=9  val=-2.3449  norm_vF=0.0000  norm_Axb=0.8911  norm_T=1.0049
# iter=10  val=-2.3809  norm_vF=0.0000  norm_Axb=0.8832  norm_T=1.0010
# Class 7
#
# iter=0  val=-1.2173  norm_vF=0.0000  norm_Axb=0.9785  norm_T=1.4009
# iter=1  val=-1.7582  norm_vF=0.0000  norm_Axb=0.9629  norm_T=1.1349
# iter=2  val=-1.9553  norm_vF=0.0000  norm_Axb=0.9531  norm_T=1.0829
# iter=3  val=-2.0772  norm_vF=0.0000  norm_Axb=0.9444  norm_T=1.0583
# iter=4  val=-2.1660  norm_vF=0.0000  norm_Axb=0.9361  norm_T=1.0431
# iter=5  val=-2.2362  norm_vF=0.0000  norm_Axb=0.9281  norm_T=1.0326
# iter=6  val=-2.2945  norm_vF=0.0000  norm_Axb=0.9202  norm_T=1.0246
# iter=7  val=-2.3445  norm_vF=0.0000  norm_Axb=0.9124  norm_T=1.0183
# iter=8  val=-2.3883  norm_vF=0.0000  norm_Axb=0.9046  norm_T=1.0131
# iter=9  val=-2.4275  norm_vF=0.0000  norm_Axb=0.8969  norm_T=1.0087
# iter=10  val=-2.4629  norm_vF=0.0000  norm_Axb=0.8891  norm_T=1.0049
# Class 8
#
# iter=0  val=-1.1833  norm_vF=0.0000  norm_Axb=0.9778  norm_T=1.3995
# iter=1  val=-1.7235  norm_vF=0.0000  norm_Axb=0.9617  norm_T=1.1339
# iter=2  val=-1.9206  norm_vF=0.0000  norm_Axb=0.9515  norm_T=1.0819
# iter=3  val=-2.0427  norm_vF=0.0000  norm_Axb=0.9426  norm_T=1.0572
# iter=4  val=-2.1318  norm_vF=0.0000  norm_Axb=0.9342  norm_T=1.0419
# iter=5  val=-2.2022  norm_vF=0.0000  norm_Axb=0.9261  norm_T=1.0313
# iter=6  val=-2.2607  norm_vF=0.0000  norm_Axb=0.9181  norm_T=1.0232
# iter=7  val=-2.3109  norm_vF=0.0000  norm_Axb=0.9101  norm_T=1.0168
# iter=8  val=-2.3549  norm_vF=0.0000  norm_Axb=0.9023  norm_T=1.0116
# iter=9  val=-2.3943  norm_vF=0.0000  norm_Axb=0.8944  norm_T=1.0071
# iter=10  val=-2.4299  norm_vF=0.0000  norm_Axb=0.8866  norm_T=1.0033
# Class 9
#
# iter=0  val=-1.1080  norm_vF=0.0000  norm_Axb=0.9768  norm_T=1.4029
# iter=1  val=-1.6519  norm_vF=0.0000  norm_Axb=0.9598  norm_T=1.1332
# iter=2  val=-1.8501  norm_vF=0.0000  norm_Axb=0.9491  norm_T=1.0806
# iter=3  val=-1.9728  norm_vF=0.0000  norm_Axb=0.9399  norm_T=1.0556
# iter=4  val=-2.0624  norm_vF=0.0000  norm_Axb=0.9312  norm_T=1.0401
# iter=5  val=-2.1334  norm_vF=0.0000  norm_Axb=0.9228  norm_T=1.0293
# iter=6  val=-2.1923  norm_vF=0.0000  norm_Axb=0.9146  norm_T=1.0211
# iter=7  val=-2.2429  norm_vF=0.0000  norm_Axb=0.9065  norm_T=1.0146
# iter=8  val=-2.2874  norm_vF=0.0000  norm_Axb=0.8985  norm_T=1.0092
# iter=9  val=-2.3271  norm_vF=0.0000  norm_Axb=0.8905  norm_T=1.0047
# iter=10  val=-2.3631  norm_vF=0.0000  norm_Axb=0.8826  norm_T=1.0008
# Class 10
#
# iter=0  val=-1.0835  norm_vF=0.0000  norm_Axb=0.9761  norm_T=1.4030
# iter=1  val=-1.6279  norm_vF=0.0000  norm_Axb=0.9585  norm_T=1.1324
# iter=2  val=-1.8263  norm_vF=0.0000  norm_Axb=0.9476  norm_T=1.0796
# iter=3  val=-1.9493  norm_vF=0.0000  norm_Axb=0.9381  norm_T=1.0544
# iter=4  val=-2.0392  norm_vF=0.0000  norm_Axb=0.9293  norm_T=1.0389
# iter=5  val=-2.1103  norm_vF=0.0000  norm_Axb=0.9208  norm_T=1.0280
# iter=6  val=-2.1694  norm_vF=0.0000  norm_Axb=0.9125  norm_T=1.0197
# iter=7  val=-2.2203  norm_vF=0.0000  norm_Axb=0.9043  norm_T=1.0132
# iter=8  val=-2.2649  norm_vF=0.0000  norm_Axb=0.8962  norm_T=1.0077
# iter=9  val=-2.3048  norm_vF=0.0000  norm_Axb=0.8882  norm_T=1.0032
# iter=10  val=-2.3410  norm_vF=0.0000  norm_Axb=0.8802  norm_T=0.9992
# 124.982037 seconds (347.63 M allocations: 64.253 GiB, 6.82% gc time)
# Accuracy: 0.9262330859886513

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_Parkinson_Christoffel()
# Out:
# Class 1
# WARNING: replacing module ClassificationModels.
# Class 2
#
# Accuracy: 0.7916666666666666

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_Parkinson_Christoffel_arb_basis()
# Out:
# largest_r=1035
# Class 1
# WARNING: replacing module ClassificationModels.
# Class 2
#
# Accuracy: 0.875

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.test_Parkinson_MLE()
# Out:
# Class 1
#
# iter=
# WARNING: replacing module ClassificationModels.
# 9951  val=-3.7527  norm_vF=0.0000  norm_Axb=0.0022  norm_T=1.2620
# iter=9952  val=-3.7526  norm_vF=0.0003  norm_Axb=0.0080  norm_T=2.2063
# iter=9953  val=-3.7527  norm_vF=0.0000  norm_Axb=0.0037  norm_T=0.7802
# iter=9954  val=-3.7528  norm_vF=0.0000  norm_Axb=0.0065  norm_T=1.2620
# iter=9955  val=-3.7527  norm_vF=0.0000  norm_Axb=0.0037  norm_T=0.7802
# iter=9956  val=-3.7529  norm_vF=0.0000  norm_Axb=0.0065  norm_T=1.2620
# iter=9957  val=-3.7528  norm_vF=0.0000  norm_Axb=0.0037  norm_T=2.1811
# iter=9958  val=-3.7528  norm_vF=0.0000  norm_Axb=0.0003  norm_T=1.2620
# iter=9959  val=-3.7527  norm_vF=0.0002  norm_Axb=0.0099  norm_T=2.1831
# iter=9960  val=-3.7528  norm_vF=0.0000  norm_Axb=0.0058  norm_T=0.7802
# iter=9961  val=-3.7529  norm_vF=0.0000  norm_Axb=0.0044  norm_T=1.2619
# iter=9962  val=-3.7528  norm_vF=0.0000  norm_Axb=0.0059  norm_T=0.7803
# iter=9963  val=-3.7530  norm_vF=0.0000  norm_Axb=0.0043  norm_T=1.2618
# iter=9964  val=-3.7529  norm_vF=0.0000  norm_Axb=0.0059  norm_T=0.7803
# iter=9965  val=-3.7531  norm_vF=0.0000  norm_Axb=0.0043  norm_T=1.2618
# iter=9966  val=-3.7529  norm_vF=0.0000  norm_Axb=0.0059  norm_T=0.7804
# iter=9967  val=-3.7531  norm_vF=0.0000  norm_Axb=0.0043  norm_T=1.2617
# iter=9968  val=-3.7530  norm_vF=0.0000  norm_Axb=0.0059  norm_T=0.7804
# iter=9969  val=-3.7532  norm_vF=0.0000  norm_Axb=0.0043  norm_T=1.2617
# iter=9970  val=-3.7531  norm_vF=0.0000  norm_Axb=0.0059  norm_T=0.7804
# iter=9971  val=-3.7532  norm_vF=0.0000  norm_Axb=0.0043  norm_T=1.2617
# iter=9972  val=-3.7531  norm_vF=0.0000  norm_Axb=0.0059  norm_T=0.7805
# iter=9973  val=-3.7533  norm_vF=0.0000  norm_Axb=0.0043  norm_T=1.2616
# iter=9974  val=-3.7532  norm_vF=0.0000  norm_Axb=0.0059  norm_T=0.7805
# iter=9975  val=-3.7533  norm_vF=0.0000  norm_Axb=0.0043  norm_T=1.2616
# iter=9976  val=-3.7532  norm_vF=0.0000  norm_Axb=0.0059  norm_T=0.7806
# iter=9977  val=-3.7534  norm_vF=0.0000  norm_Axb=0.0042  norm_T=1.2615
# iter=9978  val=-3.7533  norm_vF=0.0000  norm_Axb=0.0060  norm_T=0.7806
# iter=9979  val=-3.7534  norm_vF=0.0000  norm_Axb=0.0042  norm_T=1.2615
# iter=9980  val=-3.7533  norm_vF=0.0000  norm_Axb=0.0060  norm_T=0.7807
# iter=9981  val=-3.7535  norm_vF=0.0000  norm_Axb=0.0042  norm_T=1.2614
# iter=9982  val=-3.7534  norm_vF=0.0000  norm_Axb=0.0060  norm_T=0.7807
# iter=9983  val=-3.7535  norm_vF=0.0000  norm_Axb=0.0042  norm_T=1.2614
# iter=9984  val=-3.7534  norm_vF=0.0000  norm_Axb=0.0060  norm_T=0.7807
# iter=9985  val=-3.7536  norm_vF=0.0000  norm_Axb=0.0042  norm_T=1.2614
# iter=9986  val=-3.7535  norm_vF=0.0000  norm_Axb=0.0060  norm_T=0.7808
# iter=9987  val=-3.7536  norm_vF=0.0000  norm_Axb=0.0042  norm_T=1.2613
# iter=9988  val=-3.7535  norm_vF=0.0000  norm_Axb=0.0060  norm_T=0.7808
# iter=9989  val=-3.7537  norm_vF=0.0000  norm_Axb=0.0042  norm_T=1.2613
# iter=9990  val=-3.7536  norm_vF=0.0000  norm_Axb=0.0060  norm_T=0.7809
# iter=9991  val=-3.7537  norm_vF=0.0000  norm_Axb=0.0041  norm_T=1.2612
# iter=9992  val=-3.7536  norm_vF=0.0000  norm_Axb=0.0061  norm_T=0.7809
# iter=9993  val=-3.7538  norm_vF=0.0000  norm_Axb=0.0041  norm_T=1.2612
# iter=9994  val=-3.7537  norm_vF=0.0000  norm_Axb=0.0061  norm_T=0.7810
# iter=9995  val=-3.7539  norm_vF=0.0000  norm_Axb=0.0041  norm_T=1.2611
# iter=9996  val=-3.7538  norm_vF=0.0000  norm_Axb=0.0061  norm_T=0.7810
# iter=9997  val=-3.7539  norm_vF=0.0000  norm_Axb=0.0041  norm_T=1.2611
# iter=9998  val=-3.7538  norm_vF=0.0000  norm_Axb=0.0061  norm_T=0.7811
# iter=9999  val=-3.7540  norm_vF=0.0000  norm_Axb=0.0041  norm_T=1.2610
# iter=10000  val=-3.7539  norm_vF=0.0000  norm_Axb=0.0061  norm_T=0.7811
#
# Class 2
#
# iter=9951  val=-3.5942  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9687
# iter=9952  val=-3.5943  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0732
# iter=9953  val=-3.5942  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9687
# iter=9954  val=-3.5943  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0733
# iter=9955  val=-3.5943  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9686
# iter=9956  val=-3.5944  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0734
# iter=9957  val=-3.5943  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9685
# iter=9958  val=-3.5944  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0735
# iter=9959  val=-3.5944  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9684
# iter=9960  val=-3.5945  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0736
# iter=9961  val=-3.5944  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9683
# iter=9962  val=-3.5945  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0737
# iter=9963  val=-3.5945  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9682
# iter=9964  val=-3.5946  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0738
# iter=9965  val=-3.5945  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9681
# iter=9966  val=-3.5946  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0739
# iter=9967  val=-3.5946  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9680
# iter=9968  val=-3.5947  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0740
# iter=9969  val=-3.5946  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9679
# iter=9970  val=-3.5947  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0740
# iter=9971  val=-3.5947  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9678
# iter=9972  val=-3.5948  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0741
# iter=9973  val=-3.5947  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9678
# iter=9974  val=-3.5948  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0742
# iter=9975  val=-3.5948  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9677
# iter=9976  val=-3.5949  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0743
# iter=9977  val=-3.5948  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9676
# iter=9978  val=-3.5949  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0744
# iter=9979  val=-3.5949  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9675
# iter=9980  val=-3.5950  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0745
# iter=9981  val=-3.5949  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9674
# iter=9982  val=-3.5950  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0746
# iter=9983  val=-3.5950  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9673
# iter=9984  val=-3.5951  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0747
# iter=9985  val=-3.5950  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9672
# iter=9986  val=-3.5951  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0748
# iter=9987  val=-3.5951  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9671
# iter=9988  val=-3.5952  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0748
# iter=9989  val=-3.5951  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9670
# iter=9990  val=-3.5952  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0749
# iter=9991  val=-3.5952  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9670
# iter=9992  val=-3.5953  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0750
# iter=9993  val=-3.5952  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9669
# iter=9994  val=-3.5953  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0751
# iter=9995  val=-3.5953  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9668
# iter=9996  val=-3.5954  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0752
# iter=9997  val=-3.5953  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9667
# iter=9998  val=-3.5954  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0753
# iter=9999  val=-3.5954  norm_vF=0.0000  norm_Axb=0.0004  norm_T=0.9666
# iter=10000  val=-3.5955  norm_vF=0.0000  norm_Axb=0.0098  norm_T=1.0754
# Accuracy: 1.0

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.univariate_Christoffel()
# Out:
# WARNING: replacing module ClassificationModels.

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.univariate_Christoffel2()
# Out:
# WARNING: replacing module ClassificationModels.

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.univariate_MLE()
# Out:
# iter=9951  val=0.1135  norm_vF=0.0000  norm_Axb=0.0181  norm_T=5.3105
# iter=9952  val=0.1249  norm_vF=0.0044  norm_Axb=0.0132  norm_T=3.6200
# iter=9953  val=0.1168  norm_vF=0.0022  norm_Axb=0.0099  norm_T=4.3784
# iter=9954  val=0.1287  norm_vF=0.0058  norm_Axb=0.0171  norm_T=4.3176
# iter=9955  val=0.1150  norm_vF=0.0019  norm_Axb=0.0106  norm_T=4.7753
# iter=9956  val=0.1274  norm_vF=0.0061  norm_Axb=0.0166  norm_T=4.1200
# iter=9957  val=0.1151  norm_vF=0.0011  norm_Axb=0.0116  norm_T=4.8703
# iter=9958  val=0.1270  norm_vF=0.0059  norm_Axb=0.0155  norm_T=3.9628
# iter=9959  val=0.1160  norm_vF=0.0010  norm_Axb=0.0118  norm_T=5.0980
# iter=9960  val=0.1275  norm_vF=0.0052  norm_Axb=0.0152  norm_T=4.2311
# iter=9961  val=0.1147  norm_vF=0.0015  norm_Axb=0.0133  norm_T=4.9505
# iter=9962  val=0.1263  norm_vF=0.0051  norm_Axb=0.0137  norm_T=4.0296
# iter=9963  val=0.1147  norm_vF=0.0007  norm_Axb=0.0147  norm_T=4.8076
# iter=9964  val=0.1267  norm_vF=0.0049  norm_Axb=0.0124  norm_T=4.1509
# iter=9965  val=0.1143  norm_vF=0.0001  norm_Axb=0.0155  norm_T=5.3546
# iter=9966  val=0.1253  norm_vF=0.0044  norm_Axb=0.0114  norm_T=3.9095
# iter=9967  val=0.1149  norm_vF=0.0013  norm_Axb=0.0159  norm_T=4.8476
# iter=9968  val=0.1252  norm_vF=0.0042  norm_Axb=0.0104  norm_T=4.1234
# iter=9969  val=0.1127  norm_vF=0.0005  norm_Axb=0.0181  norm_T=4.9466
# iter=9970  val=0.1247  norm_vF=0.0040  norm_Axb=0.0090  norm_T=4.0220
# iter=9971  val=0.1133  norm_vF=0.0007  norm_Axb=0.0188  norm_T=5.1529
# iter=9972  val=0.1244  norm_vF=0.0032  norm_Axb=0.0081  norm_T=4.0653
# iter=9973  val=0.1126  norm_vF=0.0007  norm_Axb=0.0201  norm_T=4.9011
# iter=9974  val=0.1240  norm_vF=0.0032  norm_Axb=0.0068  norm_T=4.0454
# iter=9975  val=0.1125  norm_vF=0.0000  norm_Axb=0.0210  norm_T=5.3116
# iter=9976  val=0.1240  norm_vF=0.0045  norm_Axb=0.0103  norm_T=3.7358
# iter=9977  val=0.1147  norm_vF=0.0014  norm_Axb=0.0128  norm_T=4.3882
# iter=9978  val=0.1269  norm_vF=0.0053  norm_Axb=0.0143  norm_T=4.1590
# iter=9979  val=0.1143  norm_vF=0.0020  norm_Axb=0.0128  norm_T=4.7499
# iter=9980  val=0.1266  norm_vF=0.0054  norm_Axb=0.0144  norm_T=4.1602
# iter=9981  val=0.1142  norm_vF=0.0008  norm_Axb=0.0140  norm_T=4.7497
# iter=9982  val=0.1264  norm_vF=0.0055  norm_Axb=0.0132  norm_T=4.0595
# iter=9983  val=0.1145  norm_vF=0.0000  norm_Axb=0.0151  norm_T=5.3089
# iter=9984  val=0.1260  norm_vF=0.0048  norm_Axb=0.0161  norm_T=3.8573
# iter=9985  val=0.1157  norm_vF=0.0031  norm_Axb=0.0102  norm_T=4.6092
# iter=9986  val=0.1271  norm_vF=0.0054  norm_Axb=0.0165  norm_T=4.1598
# iter=9987  val=0.1148  norm_vF=0.0021  norm_Axb=0.0118  norm_T=4.8612
# iter=9988  val=0.1267  norm_vF=0.0052  norm_Axb=0.0153  norm_T=4.1082
# iter=9989  val=0.1144  norm_vF=0.0024  norm_Axb=0.0131  norm_T=5.0952
# iter=9990  val=0.1256  norm_vF=0.0048  norm_Axb=0.0137  norm_T=3.8654
# iter=9991  val=0.1152  norm_vF=0.0020  norm_Axb=0.0132  norm_T=4.8674
# iter=9992  val=0.1264  norm_vF=0.0046  norm_Axb=0.0135  norm_T=4.1825
# iter=9993  val=0.1140  norm_vF=0.0014  norm_Axb=0.0150  norm_T=4.9051
# iter=9994  val=0.1257  norm_vF=0.0044  norm_Axb=0.0120  norm_T=4.0422
# iter=9995  val=0.1139  norm_vF=0.0010  norm_Axb=0.0165  norm_T=5.0159
# iter=9996  val=0.1251  norm_vF=0.0040  norm_Axb=0.0103  norm_T=3.9867
# iter=9997  val=0.1137  norm_vF=0.0015  norm_Axb=0.0169  norm_T=5.0219
# iter=9998  val=0.1252  norm_vF=0.0036  norm_Axb=0.0100  norm_T=4.0717
# iter=9999  val=0.1137  norm_vF=0.0005  norm_Axb=0.0180  norm_T=4.7735
# iter=10000  val=0.1250  norm_vF=0.0038  norm_Axb=0.0087  norm_T=4.0320
# iter=
# WARNING: replacing module ClassificationModels.
# 9951  val=-0.0194  norm_vF=0.0001  norm_Axb=0.0208  norm_T=5.2446
# iter=9952  val=-0.0091  norm_vF=0.0035  norm_Axb=0.0067  norm_T=3.6440
# iter=9953  val=-0.0179  norm_vF=0.0003  norm_Axb=0.0207  norm_T=5.1543
# iter=9954  val=-0.0084  norm_vF=0.0030  norm_Axb=0.0064  norm_T=3.9498
# iter=9955  val=-0.0200  norm_vF=0.0004  norm_Axb=0.0221  norm_T=5.1572
# iter=9956  val=-0.0095  norm_vF=0.0032  norm_Axb=0.0055  norm_T=3.6708
# iter=9957  val=-0.0184  norm_vF=0.0000  norm_Axb=0.0217  norm_T=5.5174
# iter=9958  val=-0.0081  norm_vF=0.0041  norm_Axb=0.0097  norm_T=3.6831
# iter=9959  val=-0.0171  norm_vF=0.0014  norm_Axb=0.0121  norm_T=3.9785
# iter=9960  val=-0.0053  norm_vF=0.0054  norm_Axb=0.0162  norm_T=3.9888
# iter=9961  val=-0.0169  norm_vF=0.0023  norm_Axb=0.0117  norm_T=5.1581
# iter=9962  val=-0.0062  norm_vF=0.0056  norm_Axb=0.0159  norm_T=3.7679
# iter=9963  val=-0.0163  norm_vF=0.0015  norm_Axb=0.0122  norm_T=5.0611
# iter=9964  val=-0.0063  norm_vF=0.0055  norm_Axb=0.0144  norm_T=3.8455
# iter=9965  val=-0.0169  norm_vF=0.0015  norm_Axb=0.0134  norm_T=5.3733
# iter=9966  val=-0.0068  norm_vF=0.0050  norm_Axb=0.0140  norm_T=3.7546
# iter=9967  val=-0.0166  norm_vF=0.0019  norm_Axb=0.0138  norm_T=5.1185
# iter=9968  val=-0.0069  norm_vF=0.0049  norm_Axb=0.0133  norm_T=3.8066
# iter=9969  val=-0.0172  norm_vF=0.0016  norm_Axb=0.0145  norm_T=5.0610
# iter=9970  val=-0.0065  norm_vF=0.0047  norm_Axb=0.0131  norm_T=3.8921
# iter=9971  val=-0.0173  norm_vF=0.0010  norm_Axb=0.0153  norm_T=5.1131
# iter=9972  val=-0.0069  norm_vF=0.0046  norm_Axb=0.0122  norm_T=3.8444
# iter=9973  val=-0.0174  norm_vF=0.0016  norm_Axb=0.0160  norm_T=5.4496
# iter=9974  val=-0.0074  norm_vF=0.0042  norm_Axb=0.0115  norm_T=3.6631
# iter=9975  val=-0.0165  norm_vF=0.0012  norm_Axb=0.0153  norm_T=4.8414
# iter=9976  val=-0.0074  norm_vF=0.0048  norm_Axb=0.0115  norm_T=3.8402
# iter=9977  val=-0.0178  norm_vF=0.0006  norm_Axb=0.0164  norm_T=5.2038
# iter=9978  val=-0.0072  norm_vF=0.0045  norm_Axb=0.0112  norm_T=3.7832
# iter=9979  val=-0.0174  norm_vF=0.0007  norm_Axb=0.0171  norm_T=5.1929
# iter=9980  val=-0.0079  norm_vF=0.0041  norm_Axb=0.0100  norm_T=3.8189
# iter=9981  val=-0.0184  norm_vF=0.0015  norm_Axb=0.0179  norm_T=5.3405
# iter=9982  val=-0.0082  norm_vF=0.0037  norm_Axb=0.0096  norm_T=3.7827
# iter=9983  val=-0.0182  norm_vF=0.0015  norm_Axb=0.0182  norm_T=5.2323
# iter=9984  val=-0.0082  norm_vF=0.0035  norm_Axb=0.0091  norm_T=3.7959
# iter=9985  val=-0.0183  norm_vF=0.0015  norm_Axb=0.0184  norm_T=5.0653
# iter=9986  val=-0.0078  norm_vF=0.0035  norm_Axb=0.0091  norm_T=3.8802
# iter=9987  val=-0.0183  norm_vF=0.0007  norm_Axb=0.0187  norm_T=5.0527
# iter=9988  val=-0.0076  norm_vF=0.0035  norm_Axb=0.0089  norm_T=3.9295
# iter=9989  val=-0.0187  norm_vF=0.0009  norm_Axb=0.0191  norm_T=5.8421
# iter=9990  val=-0.0093  norm_vF=0.0042  norm_Axb=0.0084  norm_T=3.4326
# iter=9991  val=-0.0157  norm_vF=0.0007  norm_Axb=0.0126  norm_T=4.1113
# iter=9992  val=-0.0054  norm_vF=0.0054  norm_Axb=0.0148  norm_T=4.0185
# iter=9993  val=-0.0170  norm_vF=0.0014  norm_Axb=0.0132  norm_T=4.9970
# iter=9994  val=-0.0064  norm_vF=0.0056  norm_Axb=0.0144  norm_T=3.8656
# iter=9995  val=-0.0171  norm_vF=0.0006  norm_Axb=0.0141  norm_T=5.0204
# iter=9996  val=-0.0062  norm_vF=0.0054  norm_Axb=0.0135  norm_T=3.9202
# iter=9997  val=-0.0175  norm_vF=0.0003  norm_Axb=0.0147  norm_T=5.2588
# iter=9998  val=-0.0071  norm_vF=0.0048  norm_Axb=0.0120  norm_T=3.8490
# iter=9999  val=-0.0181  norm_vF=0.0019  norm_Axb=0.0166  norm_T=5.4330
# iter=10000  val=-0.0081  norm_vF=0.0043  norm_Axb=0.0108  norm_T=3.3317

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.univariate_MLE2()
# Out:
# iter=9951  val=0.1548  norm_vF=0.0036  norm_Axb=0.0103  norm_T=4.1719
# iter=9952  val=0.1428  norm_vF=0.0022  norm_Axb=0.0143  norm_T=4.2421
# iter=9953  val=0.1561  norm_vF=0.0046  norm_Axb=0.0125  norm_T=4.2352
# iter=9954  val=0.1430  norm_vF=0.0005  norm_Axb=0.0166  norm_T=4.8287
# iter=9955  val=0.1555  norm_vF=0.0043  norm_Axb=0.0101  norm_T=4.0886
# iter=9956  val=0.1434  norm_vF=0.0001  norm_Axb=0.0175  norm_T=5.1906
# iter=9957  val=0.1549  norm_vF=0.0037  norm_Axb=0.0090  norm_T=4.1345
# iter=9958  val=0.1429  norm_vF=0.0000  norm_Axb=0.0194  norm_T=5.1990
# iter=9959  val=0.1553  norm_vF=0.0043  norm_Axb=0.0119  norm_T=3.8806
# iter=9960  val=0.1433  norm_vF=0.0024  norm_Axb=0.0107  norm_T=3.9435
# iter=9961  val=0.1580  norm_vF=0.0057  norm_Axb=0.0169  norm_T=4.3238
# iter=9962  val=0.1446  norm_vF=0.0014  norm_Axb=0.0119  norm_T=4.8966
# iter=9963  val=0.1570  norm_vF=0.0054  norm_Axb=0.0148  norm_T=4.1813
# iter=9964  val=0.1445  norm_vF=0.0002  norm_Axb=0.0141  norm_T=4.8452
# iter=9965  val=0.1567  norm_vF=0.0049  norm_Axb=0.0125  norm_T=4.1630
# iter=9966  val=0.1441  norm_vF=0.0004  norm_Axb=0.0149  norm_T=5.1138
# iter=9967  val=0.1560  norm_vF=0.0048  norm_Axb=0.0117  norm_T=4.2110
# iter=9968  val=0.1434  norm_vF=0.0000  norm_Axb=0.0171  norm_T=5.1984
# iter=9969  val=0.1558  norm_vF=0.0042  norm_Axb=0.0142  norm_T=3.8049
# iter=9970  val=0.1462  norm_vF=0.0020  norm_Axb=0.0109  norm_T=4.0696
# WARNING: replacing module ClassificationModels.
# iter=9971  val=0.1570  norm_vF=0.0052  norm_Axb=0.0147  norm_T=4.1728
# iter=9972  val=0.1441  norm_vF=0.0007  norm_Axb=0.0142  norm_T=4.7248
# iter=9973  val=0.1563  norm_vF=0.0052  norm_Axb=0.0123  norm_T=4.0786
# iter=9974  val=0.1442  norm_vF=0.0000  norm_Axb=0.0154  norm_T=5.1973
# iter=9975  val=0.1566  norm_vF=0.0046  norm_Axb=0.0158  norm_T=3.9695
# iter=9976  val=0.1457  norm_vF=0.0022  norm_Axb=0.0116  norm_T=4.8183
# iter=9977  val=0.1573  norm_vF=0.0045  norm_Axb=0.0146  norm_T=4.3026
# iter=9978  val=0.1439  norm_vF=0.0024  norm_Axb=0.0132  norm_T=4.9995
# iter=9979  val=0.1560  norm_vF=0.0044  norm_Axb=0.0134  norm_T=4.2446
# iter=9980  val=0.1432  norm_vF=0.0020  norm_Axb=0.0151  norm_T=4.8463
# iter=9981  val=0.1555  norm_vF=0.0041  norm_Axb=0.0114  norm_T=4.1090
# iter=9982  val=0.1433  norm_vF=0.0005  norm_Axb=0.0173  norm_T=4.8432
# iter=9983  val=0.1552  norm_vF=0.0038  norm_Axb=0.0091  norm_T=3.9051
# iter=9984  val=0.1427  norm_vF=0.0005  norm_Axb=0.0190  norm_T=5.2452
# iter=9985  val=0.1541  norm_vF=0.0032  norm_Axb=0.0074  norm_T=3.9684
# iter=9986  val=0.1436  norm_vF=0.0000  norm_Axb=0.0198  norm_T=5.1978
# iter=9987  val=0.1559  norm_vF=0.0046  norm_Axb=0.0114  norm_T=4.2740
# iter=9988  val=0.1427  norm_vF=0.0016  norm_Axb=0.0130  norm_T=4.2419
# iter=9989  val=0.1571  norm_vF=0.0053  norm_Axb=0.0144  norm_T=4.3323
# iter=9990  val=0.1437  norm_vF=0.0006  norm_Axb=0.0141  norm_T=4.7836
# iter=9991  val=0.1564  norm_vF=0.0051  norm_Axb=0.0126  norm_T=4.1900
# iter=9992  val=0.1438  norm_vF=0.0000  norm_Axb=0.0162  norm_T=5.1979
# iter=9993  val=0.1561  norm_vF=0.0046  norm_Axb=0.0150  norm_T=3.5405
# iter=9994  val=0.1464  norm_vF=0.0018  norm_Axb=0.0114  norm_T=4.5114
# iter=9995  val=0.1572  norm_vF=0.0049  norm_Axb=0.0143  norm_T=4.3062
# iter=9996  val=0.1440  norm_vF=0.0004  norm_Axb=0.0144  norm_T=5.3256
# iter=9997  val=0.1556  norm_vF=0.0035  norm_Axb=0.0121  norm_T=3.9394
# iter=9998  val=0.1452  norm_vF=0.0021  norm_Axb=0.0101  norm_T=3.5057
# iter=9999  val=0.1587  norm_vF=0.0052  norm_Axb=0.0171  norm_T=4.2891
# iter=10000  val=0.1455  norm_vF=0.0017  norm_Axb=0.0101  norm_T=4.5922
# iter=9951  val=0.1100  norm_vF=0.0005  norm_Axb=0.0160  norm_T=5.1812
# iter=9952  val=0.1215  norm_vF=0.0042  norm_Axb=0.0112  norm_T=4.0192
# iter=9953  val=0.1086  norm_vF=0.0017  norm_Axb=0.0173  norm_T=5.1126
# iter=9954  val=0.1206  norm_vF=0.0040  norm_Axb=0.0101  norm_T=3.8607
# iter=9955  val=0.1086  norm_vF=0.0005  norm_Axb=0.0178  norm_T=4.8384
# iter=9956  val=0.1203  norm_vF=0.0041  norm_Axb=0.0085  norm_T=3.8671
# iter=9957  val=0.1078  norm_vF=0.0000  norm_Axb=0.0201  norm_T=5.3840
# iter=9958  val=0.1199  norm_vF=0.0043  norm_Axb=0.0112  norm_T=3.4991
# iter=9959  val=0.1110  norm_vF=0.0019  norm_Axb=0.0124  norm_T=4.5517
# iter=9960  val=0.1229  norm_vF=0.0056  norm_Axb=0.0148  norm_T=4.0231
# iter=9961  val=0.1096  norm_vF=0.0018  norm_Axb=0.0131  norm_T=4.8801
# iter=9962  val=0.1224  norm_vF=0.0055  norm_Axb=0.0146  norm_T=3.9620
# iter=9963  val=0.1093  norm_vF=0.0017  norm_Axb=0.0141  norm_T=5.0096
# iter=9964  val=0.1214  norm_vF=0.0054  norm_Axb=0.0133  norm_T=3.7175
# iter=9965  val=0.1101  norm_vF=0.0014  norm_Axb=0.0147  norm_T=5.0468
# iter=9966  val=0.1220  norm_vF=0.0047  norm_Axb=0.0127  norm_T=4.0021
# iter=9967  val=0.1089  norm_vF=0.0014  norm_Axb=0.0159  norm_T=5.0874
# iter=9968  val=0.1208  norm_vF=0.0047  norm_Axb=0.0115  norm_T=3.7421
# iter=9969  val=0.1095  norm_vF=0.0010  norm_Axb=0.0169  norm_T=4.9806
# iter=9970  val=0.1210  norm_vF=0.0043  norm_Axb=0.0103  norm_T=3.6280
# iter=9971  val=0.1088  norm_vF=0.0010  norm_Axb=0.0176  norm_T=5.1551
# iter=9972  val=0.1207  norm_vF=0.0040  norm_Axb=0.0098  norm_T=3.7989
# iter=9973  val=0.1096  norm_vF=0.0001  norm_Axb=0.0179  norm_T=4.8628
# iter=9974  val=0.1206  norm_vF=0.0041  norm_Axb=0.0089  norm_T=3.8244
# iter=9975  val=0.1088  norm_vF=0.0000  norm_Axb=0.0188  norm_T=5.3827
# iter=9976  val=0.1208  norm_vF=0.0043  norm_Axb=0.0125  norm_T=3.6987
# iter=9977  val=0.1108  norm_vF=0.0022  norm_Axb=0.0117  norm_T=4.5770
# iter=9978  val=0.1229  norm_vF=0.0056  norm_Axb=0.0156  norm_T=4.0074
# iter=9979  val=0.1096  norm_vF=0.0022  norm_Axb=0.0126  norm_T=4.8603
# iter=9980  val=0.1224  norm_vF=0.0056  norm_Axb=0.0150  norm_T=3.9642
# iter=9981  val=0.1093  norm_vF=0.0016  norm_Axb=0.0137  norm_T=4.9103
# iter=9982  val=0.1216  norm_vF=0.0056  norm_Axb=0.0138  norm_T=3.7662
# iter=9983  val=0.1102  norm_vF=0.0011  norm_Axb=0.0140  norm_T=5.0816
# iter=9984  val=0.1223  norm_vF=0.0049  norm_Axb=0.0134  norm_T=4.0100
# iter=9985  val=0.1091  norm_vF=0.0019  norm_Axb=0.0153  norm_T=5.1502
# iter=9986  val=0.1208  norm_vF=0.0047  norm_Axb=0.0120  norm_T=3.7203
# iter=9987  val=0.1098  norm_vF=0.0011  norm_Axb=0.0157  norm_T=4.8907
# iter=9988  val=0.1215  norm_vF=0.0047  norm_Axb=0.0114  norm_T=3.9261
# iter=9989  val=0.1092  norm_vF=0.0005  norm_Axb=0.0166  norm_T=5.1563
# iter=9990  val=0.1211  norm_vF=0.0044  norm_Axb=0.0108  norm_T=3.7942
# iter=9991  val=0.1094  norm_vF=0.0008  norm_Axb=0.0175  norm_T=5.0438
# iter=9992  val=0.1204  norm_vF=0.0042  norm_Axb=0.0094  norm_T=3.8446
# iter=9993  val=0.1086  norm_vF=0.0007  norm_Axb=0.0180  norm_T=5.0137
# iter=9994  val=0.1207  norm_vF=0.0041  norm_Axb=0.0094  norm_T=3.9153
# iter=9995  val=0.1085  norm_vF=0.0000  norm_Axb=0.0191  norm_T=5.0412
# iter=9996  val=0.1203  norm_vF=0.0038  norm_Axb=0.0082  norm_T=3.8807
# iter=9997  val=0.1080  norm_vF=0.0005  norm_Axb=0.0203  norm_T=5.1631
# iter=9998  val=0.1195  norm_vF=0.0034  norm_Axb=0.0069  norm_T=3.7936
# iter=9999  val=0.1078  norm_vF=0.0000  norm_Axb=0.0212  norm_T=4.9973
# iter=10000  val=0.1197  norm_vF=0.0032  norm_Axb=0.0061  norm_T=3.8752

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.univariate_MLE_density()
# Out:
# iter=99951  val=0.8409  norm_vF=0.0379  norm_Axb=0.0025  norm_T=7.8476
# iter=99952  val=0.8350  norm_vF=0.0394  norm_Axb=0.0028  norm_T=7.0930
# iter=99953  val=0.8401  norm_vF=0.0380  norm_Axb=0.0025  norm_T=6.1075
# iter=99954  val=0.8371  norm_vF=0.0391  norm_Axb=0.0033  norm_T=7.8599
# iter=99955  val=0.8396  norm_vF=0.0381  norm_Axb=0.0023  norm_T=6.6073
# iter=99956  val=0.8363  norm_vF=0.0391  norm_Axb=0.0036  norm_T=7.5941
# iter=99957  val=0.8402  norm_vF=0.0380  norm_Axb=0.0024  norm_T=6.9046
# iter=99958  val=0.8359  norm_vF=0.0392  norm_Axb=0.0032  norm_T=7.3913
# iter=99959  val=0.8400  norm_vF=0.0380  norm_Axb=0.0022  norm_T=6.2442
# iter=99960  val=0.8368  norm_vF=0.0391  norm_Axb=0.0035  norm_T=7.7074
# iter=99961  val=0.8399  norm_vF=0.0381  norm_Axb=0.0022  norm_T=6.7774
# iter=99962  val=0.8364  norm_vF=0.0391  norm_Axb=0.0037  norm_T=7.5428
# iter=99963  val=0.8404  norm_vF=0.0380  norm_Axb=0.0024  norm_T=7.1130
# iter=99964  val=0.8357  norm_vF=0.0393  norm_Axb=0.0031  norm_T=7.3988
# iter=99965  val=0.8397  norm_vF=0.0381  norm_Axb=0.0019  norm_T=6.0374
# iter=99966  val=0.8367  norm_vF=0.0391  norm_Axb=0.0037  norm_T=7.8489
# iter=99967  val=0.8392  norm_vF=0.0383  norm_Axb=0.0018  norm_T=7.1812
# iter=99968  val=0.8352  norm_vF=0.0392  norm_Axb=0.0040  norm_T=7.3274
# iter=99969  val=0.8402  norm_vF=0.0380  norm_Axb=0.0022  norm_T=7.3435
# iter=99970  val=0.8352  norm_vF=0.0394  norm_Axb=0.0033  norm_T=7.4345
# iter=99971  val=0.8391  norm_vF=0.0381  norm_Axb=0.0019  norm_T=6.0582
# iter=99972  val=0.8361  norm_vF=0.0392  norm_Axb=0.0037  norm_T=7.7637
# iter=99973  val=0.8390  norm_vF=0.0383  norm_Axb=0.0017  norm_T=6.8678
# iter=99974  val=0.8354  norm_vF=0.0392  norm_Axb=0.0041  norm_T=7.5108
# iter=99975  val=0.8396  norm_vF=0.0381  norm_Axb=0.0021  norm_T=6.8230
# iter=99976  val=0.8356  norm_vF=0.0393  norm_Axb=0.0036  norm_T=7.5907
# iter=99977  val=0.8391  norm_vF=0.0382  norm_Axb=0.0017  norm_T=6.2243
# iter=99978  val=0.8358  norm_vF=0.0392  norm_Axb=0.0038  norm_T=7.5766
# iter=99979  val=0.8394  norm_vF=0.0382  norm_Axb=0.0017  norm_T=7.0109
# iter=99980  val=0.8355  norm_vF=0.0392  norm_Axb=0.0041  norm_T=7.5179
# iter=99981  val=0.8397  norm_vF=0.0380  norm_Axb=0.0020  norm_T=6.6781
# iter=99982  val=0.8361  norm_vF=0.0393  norm_Axb=0.0037  norm_T=7.8169
# iter=99983  val=0.8387  norm_vF=0.0383  norm_Axb=0.0014  norm_T=6.3592
# iter=99984  val=0.8350  norm_vF=0.0393  norm_Axb=0.0039  norm_T=7.2939
# iter=99985  val=0.8395  norm_vF=0.0383  norm_Axb=0.0015  norm_T=7.4464
# iter=99986  val=0.8349  norm_vF=0.0393  norm_Axb=0.0042  norm_T=7.3998
# iter=99987  val=0.8396  norm_vF=0.0380  norm_Axb=0.0021  norm_T=6.5820
# iter=99988  val=0.8363  norm_vF=0.0392  norm_Axb=0.0038  norm_T=7.9333
# iter=99989  val=0.8386  norm_vF=0.0383  norm_Axb=0.0016  norm_T=6.8387
# iter=99990  val=0.8342  norm_vF=0.0393  norm_Axb=0.0036  norm_T=6.9550
# iter=99991  val=0.8400  norm_vF=0.0381  norm_Axb=0.0019  norm_T=7.2806
# iter=99992  val=0.8355  norm_vF=0.0393  norm_Axb=0.0038  norm_T=7.4773
# iter=99993  val=0.8398  norm_vF=0.0380  norm_Axb=0.0024  norm_T=6.4821
# iter=99994  val=0.8367  norm_vF=0.0391  norm_Axb=0.0036  norm_T=7.8376
# iter=99995  val=0.8395  norm_vF=0.0382  norm_Axb=0.0021  norm_T=7.1823
# iter=99996  val=0.8344  norm_vF=0.0393  norm_Axb=0.0031  norm_T=6.8168
# iter=99997  val=0.8408  norm_vF=0.0380  norm_Axb=0.0023  norm_T=7.0890
# iter=99998  val=0.8364  norm_vF=0.0392  norm_Axb=0.0034  norm_T=7.6045
# iter=99999  val=0.8401  norm_vF=0.0380  norm_Axb=0.0027  norm_T=6.4653
# iter=100000  val=0.8370  norm_vF=0.0390  norm_Axb=0.0033  norm_T=7.7580
# iter=
# WARNING: replacing module ClassificationModels.
# 99951  val=0.6049  norm_vF=0.0000  norm_Axb=0.0048  norm_T=2.4367
# iter=99952  val=0.5957  norm_vF=0.0000  norm_Axb=0.0051  norm_T=3.9787
# iter=99953  val=0.6048  norm_vF=0.0003  norm_Axb=0.0049  norm_T=4.5397
# iter=99954  val=0.5969  norm_vF=0.0000  norm_Axb=0.0041  norm_T=3.9764
# iter=99955  val=0.6061  norm_vF=0.0000  norm_Axb=0.0059  norm_T=3.4298
# iter=99956  val=0.5985  norm_vF=0.0000  norm_Axb=0.0023  norm_T=3.9694
# iter=99957  val=0.6077  norm_vF=0.0005  norm_Axb=0.0078  norm_T=4.5774
# iter=99958  val=0.5998  norm_vF=0.0000  norm_Axb=0.0013  norm_T=3.9672
# iter=99959  val=0.6089  norm_vF=0.0000  norm_Axb=0.0087  norm_T=2.4513
# iter=99960  val=0.5996  norm_vF=0.0000  norm_Axb=0.0012  norm_T=3.9663
# iter=99961  val=0.6088  norm_vF=0.0003  norm_Axb=0.0088  norm_T=4.5737
# iter=99962  val=0.6008  norm_vF=0.0000  norm_Axb=0.0003  norm_T=3.9641
# iter=99963  val=0.6100  norm_vF=0.0000  norm_Axb=0.0097  norm_T=2.4550
# iter=99964  val=0.6006  norm_vF=0.0000  norm_Axb=0.0002  norm_T=3.9633
# iter=99965  val=0.6098  norm_vF=0.0001  norm_Axb=0.0098  norm_T=4.5794
# iter=99966  val=0.6019  norm_vF=0.0000  norm_Axb=0.0008  norm_T=2.4247
# iter=99967  val=0.5926  norm_vF=0.0000  norm_Axb=0.0092  norm_T=3.9941
# iter=99968  val=0.6017  norm_vF=0.0000  norm_Axb=0.0008  norm_T=2.4243
# iter=99969  val=0.5924  norm_vF=0.0000  norm_Axb=0.0091  norm_T=3.9933
# iter=99970  val=0.6015  norm_vF=0.0000  norm_Axb=0.0009  norm_T=2.4239
# iter=99971  val=0.5923  norm_vF=0.0000  norm_Axb=0.0091  norm_T=3.9925
# iter=99972  val=0.6014  norm_vF=0.0000  norm_Axb=0.0009  norm_T=2.4235
# iter=99973  val=0.5921  norm_vF=0.0000  norm_Axb=0.0090  norm_T=3.9916
# iter=99974  val=0.6012  norm_vF=0.0000  norm_Axb=0.0010  norm_T=2.4233
# iter=99975  val=0.5919  norm_vF=0.0000  norm_Axb=0.0090  norm_T=3.9908
# iter=99976  val=0.6010  norm_vF=0.0002  norm_Axb=0.0011  norm_T=4.4291
# iter=99977  val=0.5935  norm_vF=0.0000  norm_Axb=0.0077  norm_T=3.9880
# iter=99978  val=0.6026  norm_vF=0.0000  norm_Axb=0.0023  norm_T=2.4277
# iter=99979  val=0.5933  norm_vF=0.0000  norm_Axb=0.0076  norm_T=3.9872
# iter=99980  val=0.6024  norm_vF=0.0000  norm_Axb=0.0024  norm_T=2.4275
# iter=99981  val=0.5931  norm_vF=0.0000  norm_Axb=0.0076  norm_T=3.9863
# iter=99982  val=0.6022  norm_vF=0.0004  norm_Axb=0.0024  norm_T=4.5019
# iter=99983  val=0.5945  norm_vF=0.0000  norm_Axb=0.0065  norm_T=3.9839
# iter=99984  val=0.6036  norm_vF=0.0003  norm_Axb=0.0035  norm_T=3.4558
# iter=99985  val=0.5960  norm_vF=0.0000  norm_Axb=0.0047  norm_T=3.9770
# iter=99986  val=0.6052  norm_vF=0.0006  norm_Axb=0.0053  norm_T=4.5442
# iter=99987  val=0.5973  norm_vF=0.0000  norm_Axb=0.0037  norm_T=3.9747
# iter=99988  val=0.6065  norm_vF=0.0000  norm_Axb=0.0063  norm_T=2.4422
# iter=99989  val=0.5972  norm_vF=0.0000  norm_Axb=0.0036  norm_T=3.9738
# iter=99990  val=0.6063  norm_vF=0.0004  norm_Axb=0.0064  norm_T=4.5507
# iter=99991  val=0.5984  norm_vF=0.0000  norm_Axb=0.0026  norm_T=3.9716
# iter=99992  val=0.6076  norm_vF=0.0000  norm_Axb=0.0074  norm_T=2.4461
# iter=99993  val=0.5983  norm_vF=0.0000  norm_Axb=0.0025  norm_T=3.9707
# iter=99994  val=0.6074  norm_vF=0.0002  norm_Axb=0.0075  norm_T=4.5589
# iter=99995  val=0.5995  norm_vF=0.0000  norm_Axb=0.0015  norm_T=3.9685
# iter=99996  val=0.6087  norm_vF=0.0000  norm_Axb=0.0085  norm_T=3.5379
# iter=99997  val=0.6010  norm_vF=0.0000  norm_Axb=0.0002  norm_T=2.4222
# iter=99998  val=0.5917  norm_vF=0.0000  norm_Axb=0.0098  norm_T=3.9947
# iter=99999  val=0.6008  norm_vF=0.0000  norm_Axb=0.0002  norm_T=2.4218
# iter=100000  val=0.5915  norm_vF=0.0000  norm_Axb=0.0097  norm_T=3.9939

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

ClassificationModels.univariate_MLE_density2()
# Out:
# iter=9951  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1192
# iter=9952  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=4.0198
# iter=9953  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.0036
# iter=9954  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9111
# iter=9955  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1190
# iter=9956  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9109
# iter=9957  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1192
# iter=9958  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=4.0198
# iter=9959  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.0036
# iter=9960  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9111
# iter=9961  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1190
# iter=9962  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9109
# iter=9963  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1191
# iter=9964  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=4.0198
# iter=9965  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.0036
# iter=9966  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9111
# iter=9967  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1190
# iter=9968  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9109
# iter=9969  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1191
# iter=9970  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=4.0198
# iter=9971  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.0035
# iter=9972  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9111
# iter=9973  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1190
# iter=9974  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9109
# iter=9975  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1191
# iter=9976  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9108
# iter=9977  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1192
# iter=9978  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=4.0199
# iter=9979  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.0033
# iter=9980  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9109
# iter=9981  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1191
# iter=9982  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9108
# iter=9983  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1192
# iter=9984  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=4.0199
# iter=9985  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.0033
# iter=9986  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9109
# iter=9987  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1191
# iter=9988  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9108
# iter=9989  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1192
# iter=9990  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=4.0199
# iter=9991  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.0033
# iter=9992  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9109
# iter=9993  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1190
# iter=9994  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9108
# iter=9995  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1192
# iter=9996  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9106
# iter=9997  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=4.1193
# iter=9998  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=4.0201
# iter=9999  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.0031
# iter=10000  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=1.9107
# WARNING: replacing module ClassificationModels.
