# %%
#=
N=1
t=1000
Y=Matrix{Float64}(undef,t,N)
randx=zeros(Float64,N)
for j=1:t
    randx=2*rand(Float64,N).-1
    randx=rand(Float64)*randx./sqrt(sum(randx.^2))
    Y[j,:]=randx
end
=#

# %%
#=
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
output_file = open(data*"/univariate_MLE_density_data2.jl","w")


write(output_file, "N = $(N)")
write(output_file, "; \n \n")
write(output_file, "t = $(t)")
write(output_file, "; \n \n")
write(output_file, "Y = ")
show(output_file, Y)
write(output_file, "; \n \n")

close(output_file)
=#

# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
include(data*"/univariate_MLE_density_data2.jl");

# %%
using Plots

r=1
p_exact(z)=0.5
scatter(Y[:,1], zeros(Float64,t),label ="sample")
plot!(p_exact, -r, r, label ="exact")

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

d=5
R=1

x=ClassificationModels.solve_opt(N,Y,t,R,d,delta=1,s=1,rho=1,numiter=1e4,eps=1e-4,tol_eig=1e-3,ball_cons=true);
# Out:
# iter=9951  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7095
# iter=9952  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3207
# iter=9953  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2212
# iter=9954  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8021
# iter=9955  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7096
# iter=9956  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3206
# iter=9957  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2212
# iter=9958  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8021
# iter=9959  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7096
# iter=9960  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3206
# iter=9961  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7094
# iter=9962  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3207
# iter=9963  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2213
# iter=9964  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8020
# iter=9965  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7095
# iter=9966  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3207
# iter=9967  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2213
# iter=9968  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8020
# iter=9969  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7095
# iter=9970  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3206
# iter=9971  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2212
# iter=9972  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8020
# iter=9973  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7095
# iter=9974  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3206
# iter=9975  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2212
# iter=9976  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8020
# iter=9977  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7096
# iter=9978  val=0.7201  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3205
# iter=9979  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2212
# iter=9980  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8020
# iter=9981  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7096
# iter=9982  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3205
# iter=9983  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7094
# iter=9984  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3206
# iter=9985  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2213
# iter=9986  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8018
# iter=9987  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7094
# iter=9988  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3206
# iter=9989  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2213
# iter=9990  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8019
# iter=9991  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7095
# iter=9992  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3205
# iter=9993  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2213
# iter=9994  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8019
# iter=9995  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7095
# iter=9996  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3205
# iter=9997  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=3.2212
# iter=9998  val=0.6607  norm_vF=0.0000  norm_Axb=0.0297  norm_T=2.8019
# iter=9999  val=0.6899  norm_vF=0.0000  norm_Axb=0.0000  norm_T=2.7095
# iter=10000  val=0.7200  norm_vF=0.0000  norm_Axb=0.0297  norm_T=3.3204
# WARNING: replacing module ClassificationModels.

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

eval_PDF=ClassificationModels.func_eval_PDF(x,N,d,R,ball_cons=true)
# Out:
# WARNING: replacing module ClassificationModels.
# (::Main.ClassificationModels.var"#eval_PDF#17"{Array{Float64,1},Int64,Int64,Array{UInt64,1},Array{Array{Float64,1},1},Array{SparseArrays.SparseMatrixCSC{UInt64,Ti} where Ti<:Integer,1},Int64,Array{Int64,1},SparseArrays.SparseMatrixCSC{UInt64,Int64}}) (generic function with 1 method)

# %%
p_approx(z)=eval_PDF([z;zeros(N-1)])
plot!(p_approx, -r, r, label = "d = $(d)",#=legend=:bottomright,=#title = "t = $(t)")

# %%
savefig(data*"/univariate_pdf_numsamp$(t).png")
