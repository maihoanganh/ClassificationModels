# %%
#=
N=1
t=1000
d=10
Y1=Matrix{Float64}(undef,t,N)
randx=zeros(Float64,N)
for j=1:t
    randx=rand(Float64,N).-0.25
    Y1[j,:]=randx
end

Y2=Matrix{Float64}(undef,t,N)
for j=1:t
    randx=-rand(Float64,N).+0.25
    Y2[j,:]=randx
end
=#

# %%
#=
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
output_file = open(data*"/univariate_MLE_data2.jl","w")

write(output_file, "d = $(d)")
write(output_file, "; \n \n")
write(output_file, "N = $(N)")
write(output_file, "; \n \n")
write(output_file, "t = $(t)")
write(output_file, "; \n \n")
write(output_file, "Y1 = ")
show(output_file, Y1)
write(output_file, "; \n \n")
write(output_file, "Y2 = ")
show(output_file, Y2)
write(output_file, "; \n \n")

close(output_file)
=#

# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
include(data*"/univariate_MLE_data2.jl");

# %%
using Plots

#p_exact(z)=0.5
scatter(Y1[:,1], zeros(Float64,t),label ="sample 1",color="Blue")
scatter!(Y2[:,1], zeros(Float64,t),label ="sample 2",color="Red")
#plot!(p_exact, -r, r, label ="exact 1")

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels


R=1

x1=ClassificationModels.solve_opt(N,Y1,t,R,d,delta=1,s=1,rho=1,numiter=1e4,eps=1e-4,tol_eig=1e-3,ball_cons=true);
# Out:
# iter=9951  val=0.1562  norm_vF=0.0052  norm_Axb=0.0115  norm_T=4.2617
# iter=9952  val=0.1432  norm_vF=0.0007  norm_Axb=0.0149  norm_T=4.7671
# iter=9953  val=0.1562  norm_vF=0.0048  norm_Axb=0.0120  norm_T=4.3629
# iter=9954  val=0.1425  norm_vF=0.0004  norm_Axb=0.0168  norm_T=4.9631
# iter=9955  val=0.1545  norm_vF=0.0045  norm_Axb=0.0097  norm_T=4.1350
# iter=9956  val=0.1421  norm_vF=0.0000  norm_Axb=0.0191  norm_T=5.1951
# iter=9957  val=0.1545  norm_vF=0.0042  norm_Axb=0.0121  norm_T=3.4364
# iter=9958  val=0.1458  norm_vF=0.0015  norm_Axb=0.0119  norm_T=4.1567
# iter=9959  val=0.1569  norm_vF=0.0051  norm_Axb=0.0139  norm_T=4.3246
# iter=9960  val=0.1436  norm_vF=0.0002  norm_Axb=0.0147  norm_T=4.7149
# iter=9961  val=0.1561  norm_vF=0.0050  norm_Axb=0.0119  norm_T=4.2720
# iter=9962  val=0.1429  norm_vF=0.0003  norm_Axb=0.0169  norm_T=5.4454
# iter=9963  val=0.1541  norm_vF=0.0044  norm_Axb=0.0118  norm_T=3.8454
# iter=9964  val=0.1438  norm_vF=0.0021  norm_Axb=0.0146  norm_T=4.9432
# iter=9965  val=0.1555  norm_vF=0.0039  norm_Axb=0.0117  norm_T=4.3871
# iter=9966  val=0.1417  norm_vF=0.0025  norm_Axb=0.0171  norm_T=4.9242
# iter=9967  val=0.1540  norm_vF=0.0035  norm_Axb=0.0095  norm_T=4.2110
# iter=9968  val=0.1411  norm_vF=0.0015  norm_Axb=0.0195  norm_T=4.8382
# iter=9969  val=0.1532  norm_vF=0.0034  norm_Axb=0.0071  norm_T=3.7617
# iter=9970  val=0.1418  norm_vF=0.0001  norm_Axb=0.0208  norm_T=4.9136
# iter=9971  val=0.1534  norm_vF=0.0029  norm_Axb=0.0055  norm_T=4.2778
# iter=9972  val=0.1404  norm_vF=0.0004  norm_Axb=0.0231  norm_T=5.1933
# iter=9973  val=0.1519  norm_vF=0.0024  norm_Axb=0.0033  norm_T=3.6262
# iter=9974  val=0.1415  norm_vF=0.0000  norm_Axb=0.0239  norm_T=5.1960
# iter=9975  val=0.1539  norm_vF=0.0042  norm_Axb=0.0073  norm_T=4.2521
# iter=9976  val=0.1414  norm_vF=0.0001  norm_Axb=0.0169  norm_T=4.0360
# iter=9977  val=0.1560  norm_vF=0.0043  norm_Axb=0.0106  norm_T=4.4474
# iter=9978  val=0.1417  norm_vF=0.0006  norm_Axb=0.0173  norm_T=4.9403
# iter=9979  val=0.1537  norm_vF=0.0043  norm_Axb=0.0086  norm_T=4.1282
# iter=9980  val=0.1412  norm_vF=0.0000  norm_Axb=0.0203  norm_T=5.1968
# iter=9981  val=0.1536  norm_vF=0.0043  norm_Axb=0.0109  norm_T=3.4737
# iter=9982  val=0.1446  norm_vF=0.0016  norm_Axb=0.0115  norm_T=3.8930
# iter=9983  val=0.1570  norm_vF=0.0057  norm_Axb=0.0149  norm_T=4.3485
# iter=9984  val=0.1435  norm_vF=0.0008  norm_Axb=0.0132  norm_T=4.7115
# iter=9985  val=0.1561  norm_vF=0.0058  norm_Axb=0.0135  norm_T=4.2513
# iter=9986  val=0.1431  norm_vF=0.0000  norm_Axb=0.0153  norm_T=5.1941
# iter=9987  val=0.1555  norm_vF=0.0053  norm_Axb=0.0159  norm_T=3.9849
# iter=9988  val=0.1441  norm_vF=0.0026  norm_Axb=0.0125  norm_T=4.8304
# iter=9989  val=0.1557  norm_vF=0.0049  norm_Axb=0.0137  norm_T=4.1421
# iter=9990  val=0.1433  norm_vF=0.0021  norm_Axb=0.0141  norm_T=5.0242
# iter=9991  val=0.1548  norm_vF=0.0044  norm_Axb=0.0122  norm_T=4.2602
# iter=9992  val=0.1419  norm_vF=0.0022  norm_Axb=0.0165  norm_T=4.9376
# iter=9993  val=0.1540  norm_vF=0.0041  norm_Axb=0.0101  norm_T=4.0570
# iter=
# WARNING: replacing module ClassificationModels.
# 9994  val=0.1421  norm_vF=0.0006  norm_Axb=0.0186  norm_T=4.7836
# iter=9995  val=0.1538  norm_vF=0.0039  norm_Axb=0.0076  norm_T=3.9049
# iter=9996  val=0.1414  norm_vF=0.0001  norm_Axb=0.0205  norm_T=5.2849
# iter=9997  val=0.1527  norm_vF=0.0032  norm_Axb=0.0060  norm_T=3.9441
# iter=9998  val=0.1424  norm_vF=0.0000  norm_Axb=0.0210  norm_T=5.1948
# iter=9999  val=0.1548  norm_vF=0.0048  norm_Axb=0.0102  norm_T=4.3074
# iter=10000  val=0.1413  norm_vF=0.0015  norm_Axb=0.0145  norm_T=4.2988

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

eval_PDF1=ClassificationModels.func_eval_PDF(x1,N,d,R,ball_cons=true)
# Out:
# WARNING: replacing module ClassificationModels.
# (::Main.ClassificationModels.var"#eval_PDF#17"{Array{Float64,1},Int64,Int64,Array{UInt64,1},Array{Array{Float64,1},1},Array{SparseArrays.SparseMatrixCSC{UInt64,Ti} where Ti<:Integer,1},Int64,Array{Int64,1},SparseArrays.SparseMatrixCSC{UInt64,Int64}}) (generic function with 1 method)

# %%
r=1

p_approx1(z)=eval_PDF1([z;zeros(N-1)])
plot!(p_approx1, -r, r, label = "estimation 1",#=legend=:bottomright,=#title = "t = $(t)",color="Blue")

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

x2=ClassificationModels.solve_opt(N,Y2,t,R,d,delta=1,s=1,rho=1,numiter=1e4,eps=1e-4,tol_eig=1e-3,ball_cons=true);
# Out:
# iter=9951  val=0.1094  norm_vF=0.0010  norm_Axb=0.0165  norm_T=5.0927
# iter=9952  val=0.1209  norm_vF=0.0047  norm_Axb=0.0108  norm_T=3.6313
# iter=9953  val=0.1086  norm_vF=0.0012  norm_Axb=0.0170  norm_T=5.0134
# iter=9954  val=0.1208  norm_vF=0.0043  norm_Axb=0.0104  norm_T=3.8431
# iter=9955  val=0.1092  norm_vF=0.0002  norm_Axb=0.0179  norm_T=4.9007
# iter=9956  val=0.1211  norm_vF=0.0042  norm_Axb=0.0094  norm_T=3.9210
# iter=9957  val=0.1083  norm_vF=0.0000  norm_Axb=0.0194  norm_T=5.3900
# iter=9958  val=0.1203  norm_vF=0.0043  norm_Axb=0.0119  norm_T=3.4729
# iter=9959  val=0.1115  norm_vF=0.0023  norm_Axb=0.0117  norm_T=4.7568
# iter=9960  val=0.1233  norm_vF=0.0055  norm_Axb=0.0155  norm_T=4.1211
# iter=9961  val=0.1095  norm_vF=0.0022  norm_Axb=0.0126  norm_T=4.8534
# iter=9962  val=0.1225  norm_vF=0.0054  norm_Axb=0.0152  norm_T=3.9741
# iter=9963  val=0.1096  norm_vF=0.0018  norm_Axb=0.0136  norm_T=4.9160
# iter=9964  val=0.1220  norm_vF=0.0054  norm_Axb=0.0140  norm_T=3.8069
# iter=9965  val=0.1100  norm_vF=0.0010  norm_Axb=0.0146  norm_T=4.9890
# iter=9966  val=0.1221  norm_vF=0.0049  norm_Axb=0.0128  norm_T=3.9338
# iter=9967  val=0.1093  norm_vF=0.0016  norm_Axb=0.0150  norm_T=5.2196
# iter=9968  val=0.1209  norm_vF=0.0048  norm_Axb=0.0123  norm_T=3.7352
# iter=9969  val=0.1101  norm_vF=0.0011  norm_Axb=0.0156  norm_T=4.9223
# iter=9970  val=0.1216  norm_vF=0.0046  norm_Axb=0.0115  norm_T=3.9274
# iter=9971  val=0.1088  norm_vF=0.0005  norm_Axb=0.0168  norm_T=5.0480
# iter=9972  val=0.1209  norm_vF=0.0047  norm_Axb=0.0107  norm_T=3.7792
# iter=9973  val=0.1098  norm_vF=0.0005  norm_Axb=0.0171  norm_T=5.1092
# iter=9974  val=0.1211  norm_vF=0.0041  norm_Axb=0.0100  norm_T=3.9652
# iter=9975  val=0.1080  norm_vF=0.0010  norm_Axb=0.0188  norm_T=5.0684
# iter=9976  val=0.1201  norm_vF=0.0040  norm_Axb=0.0087  norm_T=3.6805
# iter=9977  val=0.1091  norm_vF=0.0000  norm_Axb=0.0193  norm_T=4.8854
# iter=9978  val=0.1210  norm_vF=0.0037  norm_Axb=0.0080  norm_T=4.0083
# iter=9979  val=0.1078  norm_vF=0.0000  norm_Axb=0.0206  norm_T=5.3908
# iter=9980  val=0.1198  norm_vF=0.0040  norm_Axb=0.0107  norm_T=3.4813
# iter=9981  val=0.1108  norm_vF=0.0018  norm_Axb=0.0141  norm_T=4.7054
# iter=9982  val=0.1226  norm_vF=0.0049  norm_Axb=0.0131  norm_T=3.7548
# iter=9983  val=0.1095  norm_vF=0.0019  norm_Axb=0.0141  norm_T=4.8967
# iter=9984  val=0.1223  norm_vF=0.0047  norm_Axb=0.0136  norm_T=4.0115
# iter=9985  val=0.1094  norm_vF=0.0016  norm_Axb=0.0150  norm_T=4.9724
# iter=9986  val=0.1216  norm_vF=0.0046  norm_Axb=0.0124  norm_T=3.8094
# iter=9987  val=0.1099  norm_vF=0.0009  norm_Axb=0.0159  norm_T=5.0406
# iter=9988  val=0.1219  norm_vF=0.0042  norm_Axb=0.0115  norm_T=3.9777
# iter=9989  val=0.1091  norm_vF=0.0011  norm_Axb=0.0165  norm_T=5.1503
# iter=9990  val=0.1208  norm_vF=0.0043  norm_Axb=0.0108  norm_T=3.7567
# iter=9991  val=0.1098  norm_vF=0.0008  norm_Axb=0.0170  norm_T=4.9775
# iter=9992  val=0.1212  norm_vF=0.0040  norm_Axb=0.0100  norm_T=3.9621
# WARNING: replacing module ClassificationModels.
# iter=9993  val=0.1080  norm_vF=0.0008  norm_Axb=0.0187  norm_T=5.1980
# iter=9994  val=0.1199  norm_vF=0.0039  norm_Axb=0.0086  norm_T=3.6355
# iter=9995  val=0.1098  norm_vF=0.0003  norm_Axb=0.0182  norm_T=4.9197
# iter=9996  val=0.1208  norm_vF=0.0037  norm_Axb=0.0086  norm_T=3.9378
# iter=9997  val=0.1082  norm_vF=0.0000  norm_Axb=0.0198  norm_T=5.1004
# iter=9998  val=0.1203  norm_vF=0.0036  norm_Axb=0.0076  norm_T=3.8432
# iter=9999  val=0.1086  norm_vF=0.0000  norm_Axb=0.0199  norm_T=5.3897
# iter=10000  val=0.1206  norm_vF=0.0042  norm_Axb=0.0114  norm_T=3.7026

# %%
include("../src/ClassificationModels.jl")
using .ClassificationModels

eval_PDF2=ClassificationModels.func_eval_PDF(x2,N,d,R,ball_cons=true)
# Out:
# WARNING: replacing module ClassificationModels.
# (::Main.ClassificationModels.var"#eval_PDF#17"{Array{Float64,1},Int64,Int64,Array{UInt64,1},Array{Array{Float64,1},1},Array{SparseArrays.SparseMatrixCSC{UInt64,Ti} where Ti<:Integer,1},Int64,Array{Int64,1},SparseArrays.SparseMatrixCSC{UInt64,Int64}}) (generic function with 1 method)

# %%
#r=1

p_approx2(z)=eval_PDF2([z;zeros(N-1)])
plot!(p_approx2, -r, r, label = "estimation 2",#=legend=:bottomright,=#title = "t = $(t)",color="Red")

# %%
savefig(data*"/univariate_classification_numsamp$(t).png")
